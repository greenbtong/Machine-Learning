# %% [markdown]
# ### week 3
#
# # Linear Algebra and Linear Regression
#
# ### written by Neil Lawrence (2015), with some modification by YG (2017)

# %% [markdown]
# ### Sum of Squares Error
#
# Last week we considered a cost function for minimization of the error. We considered items (films) and users and assumed that each movie rating $y_{i,j}$ could be summarised by an inner product between a vector associated with the item $\mathbf{v}_j$ and one associated with the user $\mathbf{u}_i$. We justified the inner product as a measure of similarity in the space of 'movie subjects', where both the users and the items lived, giving the analogy of a library.
#
# To make predictions we encouraged the similarity to be high if the movie rating was high using the quadratic error function,
# $$
#   E_{i,j}(\mathbf{u}_i,\mathbf{v}_j) = (\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j})^2
# $$
# which we then summed across all the observations to form the total error
# $$
#   E(\mathbf{U},\mathbf{V}) = \sum_{i,j} s_{i,j} (\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j})^2
# $$
# where $s_{i,j}$ is an indicator variable which is set to 1 if the rating of movie $j$ by user $i$ is provided in our data set.
#
# This is known as a sum of squares error. Minimizing it was first proposed by [Legendre](http://en.wikipedia.org/wiki/Adrien-Marie_Legendre) in 1805. His book, which was on the orbit of comets, is available on google books, we can take a look at the relevant page by calling the code below.

# %%
import pods
pods.notebook.display_google_book(id='spcAAAAAMAAJ', page=72)
# Out:
# <iframe frameborder="0" scrolling="yes" style="border:0px" src="http://books.google.co.uk/books?id=spcAAAAAMAAJ&pg=PA72&output=embed", width=700 height=500></iframe>

# %% [markdown]
# Of course, the main text is in French, but the key part we are interested in can be roughly translated as
#
# "In most matters where we take measures data through observation, the most accurate results they can offer, it is almost always leads to a system of equations of the form
# $$
#   E = a + bx + cy + fz + etc
# $$
# where $a$, $b$, $c$, $f$ etc are the known coefficients and $x$, $y$, $z$ etc are unknown and must be determined by the condition that the value of $E$ is reduced, for each equation, to an amount or zero or very small."
#
# He continues
#
# "Of all the principles that we can offer for this item, I think it is not broader, more accurate, nor easier than the one we have used in previous research application, and that is to make the minimum sum of the squares of the errors. By this means, it is between the errors a kind of balance that prevents extreme to prevail, is very specific to make known the state of the closest to the truth system. The sum of the squares of the errors $E^2 + \left.E^\prime\right.^2 + \left.E^{\prime\prime}\right.^2 + etc$ being
# \begin{align*}
#     & (a + bx + cy + fz + etc)^2 \\
#   + & (a^\prime + b^\prime x + c^\prime y + f^\prime z + etc)^2 \\
#   + & (a^{\prime\prime} + b^{\prime\prime} x + c^{\prime\prime} y + f^{\prime\prime}z + etc)^2 \\
#   + & etc
# \end{align*}
# if we wanted a minimum, by varying x alone, we will have the equation ..."
#
# This is the earliest known printed version of the problem of least squares. The notation, however, is a little awkward for mordern eyes. In particular Legendre doesn't make use of the sum sign,
# $$
#   \sum_{i=1}^3 z_i = z_1 + z_2 + z_3
# $$
# nor does he make use of the inner product.
#
# In our notation, if we were to do linear regression, we would need to subsititue:
# \begin{align*}
#   a & \leftarrow y_1-c \\
#   a^\prime & \leftarrow y_2-c \\
#   a^{\prime\prime} & \leftarrow y_3 -c \qquad etc
# \end{align*}
# to introduce the data observations $\{y_i\}_{i=1}^{n}$ alongside $c$, the offset. We would then introduce the input locations
# \begin{align*}
#   b & \leftarrow x_1 \\
#   b^\prime & \leftarrow x_2 \\
#   b^{\prime\prime} & \leftarrow x_3 \qquad etc
# \end{align*}
# and finally the gradient of the function
# $$
#   x \leftarrow -m
# $$
# The remaining coefficients ($c$ and $f$) would then be zero. That would give us
# \begin{align*}
#   & (y_1 - (mx_1+c))^2 \\
#   + & (y_2 -(mx_2 + c))^2 \\
#   + & (y_3 -(mx_3 + c))^2 \\
#   + & etc
# \end{align*}
# which we would write in the modern notation for sums as
# $$
#   \sum_{i=1}^n (y_i - (mx_i + c))^2
# $$
# which is recognised as the sum of squares error for a linear regression.
#
# This shows the advantage of modern [summation operator](http://en.wikipedia.org/wiki/Summation), $\sum$, in keeping our mathematical notation compact. Whilst it may look more complicated the first time you see it, understanding the mathematical rules that go around it, allows us to go much further with the notation.
#
# Inner products (or [dot products](http://en.wikipedia.org/wiki/Dot_product)) are similar. They allow us to write
# $$
#   \sum_{i=1}^q u_i v_i
# $$
# in a more compact notation, $\mathbf{u}^\top \cdot \mathbf{v}$ .
# Here we are using bold face to represent vectors, and we assume that the individual elements of a vector $\mathbf{z}$ are given as a series of scalars
# $$
#   \mathbf{z} = \begin{bmatrix} z_1 \\ \vdots \\ z_n \end{bmatrix}
# $$
# which are each indexed by their position in the vector.

# %% [markdown]
# ### Linear Algebra
#
# Linear algebra provides a very similar role, when we introduce [linear algebra](http://en.wikipedia.org/wiki/Linear_algebra), it is because we are faced with a large number of addition and multiplication operations. These operations need to be done together and would be very tedious to write down as a group. So the first reason we reach for linear algebra is for a more compact representation of our mathematical formulae.

# %% [markdown]
# ### Example: Olympic Marathons
#
# Now we will load in the Olympic marathon data. This is data of times for the men's marathon from the first olympics in 1896 up until the London 2012 olympics.

# %%
data = pods.datasets.olympic_marathon_men()
x = data['X']
y = data['Y']

# %% [markdown]
# You can see what these values are by typing:

# %%
print(x)
print(y)
# Out:
# [[ 1896.]
#  [ 1900.]
#  [ 1904.]
#  [ 1908.]
#  [ 1912.]
#  [ 1920.]
#  [ 1924.]
#  [ 1928.]
#  [ 1932.]
#  [ 1936.]
#  [ 1948.]
#  [ 1952.]
#  [ 1956.]
#  [ 1960.]
#  [ 1964.]
#  [ 1968.]
#  [ 1972.]
#  [ 1976.]
#  [ 1980.]
#  [ 1984.]
#  [ 1988.]
#  [ 1992.]
#  [ 1996.]
#  [ 2000.]
#  [ 2004.]
#  [ 2008.]
#  [ 2012.]]
# [[ 4.47083333]
#  [ 4.46472926]
#  [ 5.22208333]
#  [ 4.15467867]
#  [ 3.90331675]
#  [ 3.56951267]
#  [ 3.82454477]
#  [ 3.62483707]
#  [ 3.59284275]
#  [ 3.53880792]
#  [ 3.67010309]
#  [ 3.39029111]
#  [ 3.43642612]
#  [ 3.20583007]
#  [ 3.13275665]
#  [ 3.32819844]
#  [ 3.13583758]
#  [ 3.0789588 ]
#  [ 3.10581822]
#  [ 3.06552909]
#  [ 3.09357349]
#  [ 3.16111704]
#  [ 3.14255244]
#  [ 3.08527867]
#  [ 3.10265829]
#  [ 2.99877553]
#  [ 3.03392977]]

# %% [markdown]
# Note that they are not `pandas` data frames for this example, they are just arrays of dimensionality $n\times 1$, where $n$ is the number of data.
#
# The aim of this lab is to have you coding linear regression in python. We will do it in two ways, once using iterative updates (coordinate ascent) and then using linear algebra. The linear algebra approach will not only work much better, it is easy to extend to multiple input linear regression and *non-linear* regression using basis functions.

# %% [markdown]
# ### Plotting the Data
#
# You can make a plot of $y$ vs $x$ with the following command:

# %%
# %matplotlib inline 
import pylab as plt

plt.plot(x, y, 'rx')
plt.xlabel('year')
plt.ylabel('pace in min/km')

# %% [markdown]
# ### Maximum Likelihood: Iterative Solution
#
# Now we will take the maximum likelihood approach we derived in the lecture to fit a line, $y_i = mx_i + c$, to the data you've plotted. We are trying to minimize the error function:
# $$
#   E(m, c) = \sum_{i=1}^n (y_i - mx_i - c)^2
# $$
# with respect to $m$, $c$ and $\sigma^2$.
#
# We can start with an initial guess for $m$, then we use the maximum likelihood update to find an estimate for the offset $c$.

# %%
m = -0.4
c = 80

# %% [markdown]
# ### Coordinate Descent
#
# In the movie recommender system example, we minimised the objective function by gradient (steepest) descent based gradient methods. Our updates required us to compute the gradient at the position we were located, then to update the gradient according to the direction of steepest descent. This time, we will take another approach. It is known as [**coordinate descent**](https://en.wikipedia.org/wiki/Coordinate_descent). In coordinate descent, we choose to move one parameter at a time. Ideally, we design an algorithm that at each step moves the parameter to its minimum value. At each step we choose to move the individual parameter to its minimum.
#
# To find the minimum, we look for the point in the curve where the gradient is zero. This can be found by taking the gradient of $E(m,c)$ with respect to the parameter.
#
# #### Update for Offset
#
# Let's consider the parameter $c$ first. The gradient goes nicely through the summation operator, and we obtain
# $$
#   \frac{\partial E(m,c)}{\partial c} = -\sum_{i=1}^n 2(y_i - mx_i - c)
# $$
# Now we want the point that is a minimum. A minimum is an example of a [*stationary point*](http://en.wikipedia.org/wiki/Stationary_point), the stationary points are those points of the function where the gradient is zero. They are found by solving the equation for $\frac{\partial E(m,c)}{\partial c} = 0$. Substituting in to our gradient, we can obtain the following equation,
# $$
#   0 = -\sum_{i=1}^n 2(y_i - mx_i - c)
# $$
# which can be reorganised as follows,
# $$
#   c^* = \frac{\sum_{i=1}^n (y_i - m^* x_i)}{n}
# $$
# The fact that the stationary point is easily extracted in this manner implies that the solution is *unique*. There is only one stationary point for this system. Traditionally when trying to determine the type of stationary point we have encountered we now compute the *second derivative*,
# $$
#   \frac{\partial^2 E(m,c)}{\partial c^2} = 2n
# $$
# The second derivative is positive, which in turn implies that we have found a minimum of the function. This means that setting $c$ in this way will take us to the lowest point along that axes.

# %%
# set c to the minimum
c = (y - m*x).mean()
print(c)
# Out:
# 786.019771145

# %% [markdown]
# #### Update for Slope
#
# Now we have the offset set to the minimum value, in coordinate descent, the next step is to optimise another parameter. Only one further parameter remains. That is the slope of the system.
#
# Now we can turn our attention to the slope. We once again perform the same set of computations to find the minima. We end up with an update equation of the following form.
# $$
#   m^* = \frac{\sum_{i=1}^n (y_i - c)x_i}{\sum_{i=1}^n x_i^2}
# $$
# The next thing we are going to do is a little differentiation practice.

# %% [markdown]
# ### Assignment Question 1
#
# Derive the the gradient of the objective function with respect to the slope, $m$. Rearrange it to show that the update equation written above does find the stationary points of the objective function. By computing its derivative show that it's a minimum.
#
# *10 marks*

# %% [markdown]
# #### Question 1 Answer
#
# Given $E$, derive the gradient of the objective function with respect to the slope, $m$,
#
# $$
#   E(m, c) = \sum_{i=1}^n (y_i - mx_i - c)^2
# $$
#
# Find the minimum,
#
# $$
#   0 = \frac{\partial E(m,c)}{\partial m} = -\sum_{i=1}^n 2x_i(y_i - mx_i - c)
# $$
#
# which can be reorganised as follows,
# $$
#   m^* = \frac{\sum_{i=1}^n (y_i - c) x_i}{\sum_{i=1}^n x_i^2}
# $$
#
# Next, get the double derivative
#
# $$
#   \frac{\partial^2 E(m,c)}{\partial m^2} = \sum_{i=1}^n 2x_i^2
# $$
#
# The second derivative is positive, which in turn implies that we have found a minimum of the function.

# %%
m = ((y - c)*x).sum()/(x**2).sum()
print(m)
# Out:
# -0.3998724073

# %% [markdown]
# We can have a look at how good our fit is by computing the prediction across the input space. First create a vector of 'test points',

# %%
import numpy as np

x_test = np.linspace(1890, 2020, 130)[:, None]

# %% [markdown]
# Now use this vector to compute some test predictions,

# %%
f_test = m*x_test + c

# %% [markdown]
# Now plot those test predictions with a blue line on the same plot as the data,

# %%
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# The fit isn't very good, we need to iterate between these parameter updates in a loop to improve the fit, we have to do this several times,

# %%
for i in np.arange(10):
    m = ((y - c)*x).sum()/(x*x).sum()
    c = (y-m*x).sum()/y.shape[0]
print(m)
print(c)
# Out:
# -0.398725964251
# 783.527379727

# %% [markdown]
# And let's try plotting the result again,

# %%
f_test = m*x_test + c
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# Clearly we need more iterations than 10! In the next question you will add more iterations and report on the error as optimisation proceeds.

# %% [markdown]
# ### Assignment Question 2
#
# There is a problem here, we seem to need many interations to get to a good solution. Let's explore what's going on. Write code which alternates between updates of `c` and `m`. Include the following features in your code.
#
# (a) Initialise with `m = -0.4` and `c = 80`.
# (b) Every 10 iterations compute the value of the objective function for the training data and print it to the screen (you'll find hints on this in the lab from last week.
# (c) Cause the code to stop running when the error change over less than 10 iterations is smaller than $1\times10^{-4}$. This is known as a stopping criterion.
#
# Why do we need so many iterations to get to the solution?
#
# *10 marks*

# %%
# Question 2 Answer Code

# initialise 
m = -0.4
c = 80

# %%
# iterate the value of the objective function and print it out
def compute_value(m, c, x, y):
    for i in np.arange(10):
        m = ((y - c)*x).sum()/(x*x).sum()
        c = (y-m*x).sum()/y.shape[0]
    return m, c

# E(m,c) = sum((y - m x - c)^2)    
def objective_function(m, c, x, y):
    obj = 0.
    for i in range(len(x)):
        prediction = m * x[i] - c # m x - c
        diff = -y[i] + prediction  # y - m x - c
        obj += diff*diff # diff^2
    return obj

# %%
# print out objective function and continue to run until error change is < 1*10^-4
m, c = compute_value(m, c, x, y)
error_previous = objective_function(m, c, x, y)
error = 1000
while(1) :
    if (error < 1e-4):
        break
    m, c = compute_value(m, c, x, y)
    error_new = objective_function(m, c, x, y)
    error = error_previous - error_new 
    print("m = ", m, ", c = ", c, ", objective function = ", error_new, "error change  = ", error)
    error_previous = error_new
f_test = m*x_test + c
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# ('m = ', -0.038932157701863868, ', c = ', 79.664088545820306, ', objective function = ', array([ 685432.5670297]), 'error change  = ', array([ 2888.5122132]))
# ('m = ', -0.038846727474039083, ', c = ', 79.496961707534922, ', objective function = ', array([ 682559.60719969]), 'error change  = ', array([ 2872.95983002]))
# ('m = ', -0.038761578475469863, ', c = ', 79.330385037000624, ', objective function = ', array([ 679702.10883086]), 'error change  = ', array([ 2857.49836883]))
# ('m = ', -0.038676709780372742, ', c = ', 79.164356723110615, ', objective function = ', array([ 676859.98156165]), 'error change  = ', array([ 2842.12726921]))
# ('m = ', -0.038592120466011834, ', c = ', 78.99887496072013, ', objective function = ', array([ 674033.13558734]), 'error change  = ', array([ 2826.84597431]))
# ('m = ', -0.038507809612688841, ', c = ', 78.833937950626776, ', objective function = ', array([ 671221.48165654]), 'error change  = ', array([ 2811.6539308]))
# ('m = ', -0.038423776303733011, ', c = ', 78.669543899550973, ', objective function = ', array([ 668424.93106766]), 'error change  = ', array([ 2796.55058889]))
# ('m = ', -0.038340019625491203, ', c = ', 78.50569102011643, ', objective function = ', array([ 665643.39566541]), 'error change  = ', array([ 2781.53540225]))
# ('m = ', -0.038256538667317937, ', c = ', 78.342377530830817, ', objective function = ', array([ 662876.78783735]), 'error change  = ', array([ 2766.60782805]))
# ('m = ', -0.038173332521565559, ', c = ', 78.179601656066367, ', objective function = ', array([ 660125.02051045]), 'error change  = ', array([ 2751.7673269]))
# ('m = ', -0.038090400283574258, ', c = ', 78.017361626040397, ', objective function = ', array([ 657388.00714763]), 'error change  = ', array([ 2737.01336282]))
# ('m = ', -0.038007741051662255, ', c = ', 77.85565567679626, ', objective function = ', array([ 654665.66174438]), 'error change  = ', array([ 2722.34540325]))
# ('m = ', -0.037925353927116115, ', c = ', 77.694482050184149, ', objective function = ', array([ 651957.89882537]), 'error change  = ', array([ 2707.76291901]))
# ('m = ', -0.03784323801418088, ', c = ', 77.533838993841954, ', objective function = ', array([ 649264.63344111]), 'error change  = ', array([ 2693.26538426]))
# ('m = ', -0.037761392420050277, ', c = ', 77.373724761176078, ', objective function = ', array([ 646585.78116458]), 'error change  = ', array([ 2678.85227653]))
# ('m = ', -0.037679816254857126, ', c = ', 77.214137611342665, ', objective function = ', array([ 643921.25808793]), 'error change  = ', array([ 2664.52307664]))
# ('m = ', -0.037598508631663641, ', c = ', 77.055075809228583, ', objective function = ', array([ 641270.98081922]), 'error change  = ', array([ 2650.27726872]))
# ('m = ', -0.037517468666451712, ', c = ', 76.896537625432515, ', objective function = ', array([ 638634.86647906]), 'error change  = ', array([ 2636.11434015]))
# ('m = ', -0.037436695478113409, ', c = ', 76.738521336246251, ', objective function = ', array([ 636012.83269746]), 'error change  = ', array([ 2622.0337816]))
# ('m = ', -0.03735618818844124, ', c = ', 76.581025223635734, ', objective function = ', array([ 633404.79761051]), 'error change  = ', array([ 2608.03508695]))
# ('m = ', -0.03727594592211881, ', c = ', 76.424047575222744, ', objective function = ', array([ 630810.67985724]), 'error change  = ', array([ 2594.11775327]))
# ('m = ', -0.037195967806711042, ', c = ', 76.267586684265765, ', objective function = ', array([ 628230.39857637]), 'error change  = ', array([ 2580.28128087]))
# ('m = ', -0.037116252972655035, ', c = ', 76.111640849642129, ', objective function = ', array([ 625663.8734032]), 'error change  = ', array([ 2566.52517317]))
# ('m = ', -0.037036800553250267, ', c = ', 75.956208375828794, ', objective function = ', array([ 623111.0244664]), 'error change  = ', array([ 2552.8489368]))
# ('m = ', -0.036957609684649402, ', c = ', 75.801287572884448, ', objective function = ', array([ 620571.77238493]), 'error change  = ', array([ 2539.25208147]))
# ('m = ', -0.03687867950584877, ', c = ', 75.646876756430771, ', objective function = ', array([ 618046.03826492]), 'error change  = ', array([ 2525.73412001]))
# ('m = ', -0.036800009158679078, ', c = ', 75.492974247634351, ', objective function = ', array([ 615533.74369655]), 'error change  = ', array([ 2512.29456836]))
# ('m = ', -0.036721597787796045, ', c = ', 75.339578373188374, ', objective function = ', array([ 613034.81075105]), 'error change  = ', array([ 2498.93294551]))
# ('m = ', -0.036643444540671151, ', c = ', 75.186687465294398, ', objective function = ', array([ 610549.16197756]), 'error change  = ', array([ 2485.64877349]))
# ('m = ', -0.036565548567582304, ', c = ', 75.034299861644286, ', objective function = ', array([ 608076.72040018]), 'error change  = ', array([ 2472.44157738]))
# ('m = ', -0.036487909021604571, ', c = ', 74.882413905401918, ', objective function = ', array([ 605617.40951493]), 'error change  = ', array([ 2459.31088525]))
# ('m = ', -0.036410525058601095, ', c = ', 74.731027945185502, ', objective function = ', array([ 603171.15328676]), 'error change  = ', array([ 2446.25622818]))
# ('m = ', -0.036333395837213851, ', c = ', 74.580140335049421, ', objective function = ', array([ 600737.87614656]), 'error change  = ', array([ 2433.2771402]))
# ('m = ', -0.036256520518854474, ', c = ', 74.429749434466359, ', objective function = ', array([ 598317.50298826]), 'error change  = ', array([ 2420.3731583]))
# ('m = ', -0.036179898267695118, ', c = ', 74.279853608309438, ', objective function = ', array([ 595909.95916585]), 'error change  = ', array([ 2407.54382241]))
# ('m = ', -0.036103528250659482, ', c = ', 74.130451226834538, ', objective function = ', array([ 593515.17049047]), 'error change  = ', array([ 2394.78867537]))
# ('m = ', -0.03602740963741366, ', c = ', 73.981540665662536, ', objective function = ', array([ 591133.06322757]), 'error change  = ', array([ 2382.1072629]))
# ('m = ', -0.035951541600357184, ', c = ', 73.833120305761668, ', objective function = ', array([ 588763.56409395]), 'error change  = ', array([ 2369.49913362]))
# ('m = ', -0.035875923314613867, ', c = ', 73.685188533429738, ', objective function = ', array([ 586406.60025497]), 'error change  = ', array([ 2356.96383898]))
# ('m = ', -0.035800553958023042, ', c = ', 73.537743740276866, ', objective function = ', array([ 584062.09932166]), 'error change  = ', array([ 2344.5009333]))
# ('m = ', -0.035725432711130468, ', c = ', 73.390784323207768, ', objective function = ', array([ 581729.98934797]), 'error change  = ', array([ 2332.1099737]))
# ('m = ', -0.035650558757179519, ', c = ', 73.244308684404473, ', objective function = ', array([ 579410.19882787]), 'error change  = ', array([ 2319.7905201]))
# ('m = ', -0.035575931282102249, ', c = ', 73.098315231308874, ', objective function = ', array([ 577102.65669265]), 'error change  = ', array([ 2307.54213522]))
# ('m = ', -0.035501549474510591, ', c = ', 72.95280237660549, ', objective function = ', array([ 574807.29230812]), 'error change  = ', array([ 2295.36438453]))
# ('m = ', -0.035427412525687436, ', c = ', 72.807768538204044, ', objective function = ', array([ 572524.03547186]), 'error change  = ', array([ 2283.25683626]))
# ('m = ', -0.035353519629577917, ', c = ', 72.663212139222381, ', objective function = ', array([ 570252.81641048]), 'error change  = ', array([ 2271.21906138]))
# ('m = ', -0.035279869982780696, ', c = ', 72.519131607969442, ', objective function = ', array([ 567993.56577693]), 'error change  = ', array([ 2259.25063355]))
# ('m = ', -0.035206462784539087, ', c = ', 72.3755253779279, ', objective function = ', array([ 565746.21464778]), 'error change  = ', array([ 2247.35112914]))
# ('m = ', -0.035133297236732489, ', c = ', 72.232391887737364, ', objective function = ', array([ 563510.69452058]), 'error change  = ', array([ 2235.5201272]))
# ('m = ', -0.035060372543867645, ', c = ', 72.089729581177323, ', objective function = ', array([ 561286.93731115]), 'error change  = ', array([ 2223.75720943]))
# ('m = ', -0.034987687913069922, ', c = ', 71.947536907150081, ', objective function = ', array([ 559074.87535095]), 'error change  = ', array([ 2212.06196019]))
# ('m = ', -0.03491524255407482, ', c = ', 71.805812319664099, ', objective function = ', array([ 556874.44138449]), 'error change  = ', array([ 2200.43396646]))
# ('m = ', -0.034843035679219356, ', c = ', 71.664554277817231, ', objective function = ', array([ 554685.56856667]), 'error change  = ', array([ 2188.87281782]))
# ('m = ', -0.034771066503433437, ', c = ', 71.523761245779724, ', objective function = ', array([ 552508.19046022]), 'error change  = ', array([ 2177.37810646]))
# ('m = ', -0.034699334244231349, ', c = ', 71.383431692777719, ', objective function = ', array([ 550342.24103308]), 'error change  = ', array([ 2165.94942713]))
# ('m = ', -0.034627838121703267, ', c = ', 71.243564093076486, ', objective function = ', array([ 548187.65465592]), 'error change  = ', array([ 2154.58637716]))
# ('m = ', -0.034556577358506764, ', c = ', 71.10415692596392, ', objective function = ', array([ 546044.36609951]), 'error change  = ', array([ 2143.28855641]))
# ('m = ', -0.034485551179858305, ', c = ', 70.965208675733848, ', objective function = ', array([ 543912.31053224]), 'error change  = ', array([ 2132.05556727]))
# ('m = ', -0.034414758813524959, ', c = ', 70.826717831669896, ', objective function = ', array([ 541791.4235176]), 'error change  = ', array([ 2120.88701464]))
# ('m = ', -0.034344199489815909, ', c = ', 70.688682888028708, ', objective function = ', array([ 539681.64101168]), 'error change  = ', array([ 2109.78250592]))
# ('m = ', -0.034273872441574059, ', c = ', 70.551102344023718, ', objective function = ', array([ 537582.89936071]), 'error change  = ', array([ 2098.74165098]))
# ('m = ', -0.034203776904167753, ', c = ', 70.413974703808861, ', objective function = ', array([ 535495.13529856]), 'error change  = ', array([ 2087.76406215]))
# ('m = ', -0.034133912115482445, ', c = ', 70.277298476462278, ', objective function = ', array([ 533418.28594432]), 'error change  = ', array([ 2076.84935423]))
# ('m = ', -0.034064277315912404, ', c = ', 70.141072175970066, ', objective function = ', array([ 531352.28879989]), 'error change  = ', array([ 2065.99714443]))
# ('m = ', -0.033994871748352459, ', c = ', 70.005294321210201, ', objective function = ', array([ 529297.0817475]), 'error change  = ', array([ 2055.20705239]))
# ('m = ', -0.033925694658189738, ', c = ', 69.869963435936313, ', objective function = ', array([ 527252.60304738]), 'error change  = ', array([ 2044.47870012]))
# ('m = ', -0.033856745293295527, ', c = ', 69.735078048761793, ', objective function = ', array([ 525218.79133533]), 'error change  = ', array([ 2033.81171205]))
# ('m = ', -0.033788022904017022, ', c = ', 69.600636693143613, ', objective function = ', array([ 523195.58562037]), 'error change  = ', array([ 2023.20571496]))
# ('m = ', -0.033719526743169276, ', c = ', 69.46663790736666, ', objective function = ', array([ 521182.92528237]), 'error change  = ', array([ 2012.660338]))
# ('m = ', -0.033651256066026973, ', c = ', 69.333080234527543, ', objective function = ', array([ 519180.75006974]), 'error change  = ', array([ 2002.17521263]))
# ('m = ', -0.033583210130316378, ', c = ', 69.199962222518863, ', objective function = ', array([ 517189.00009707]), 'error change  = ', array([ 1991.74997267]))
# ('m = ', -0.03351538819620721, ', c = ', 69.06728242401347, ', objective function = ', array([ 515207.61584286]), 'error change  = ', array([ 1981.38425421]))
# ('m = ', -0.033447789526304769, ', c = ', 68.935039396448772, ', objective function = ', array([ 513236.53814719]), 'error change  = ', array([ 1971.07769567]))
# ('m = ', -0.033380413385641676, ', c = ', 68.803231702010805, ', objective function = ', array([ 511275.70820945]), 'error change  = ', array([ 1960.82993773]))
# ('m = ', -0.033313259041670026, ', c = ', 68.671857907618872, ', objective function = ', array([ 509325.06758611]), 'error change  = ', array([ 1950.64062334]))
# ('m = ', -0.033246325764253459, ', c = ', 68.540916584909866, ', objective function = ', array([ 507384.55818842]), 'error change  = ', array([ 1940.50939769]))
# ('m = ', -0.033179612825659135, ', c = ', 68.410406310222754, ', objective function = ', array([ 505454.1222802]), 'error change  = ', array([ 1930.43590822]))
# ('m = ', -0.033113119500549813, ', c = ', 68.280325664582961, ', objective function = ', array([ 503533.70247562]), 'error change  = ', array([ 1920.41980458]))
# ('m = ', -0.033046845065976091, ', c = ', 68.150673233687243, ', objective function = ', array([ 501623.24173698]), 'error change  = ', array([ 1910.46073864]))
# ('m = ', -0.032980788801368344, ', c = ', 68.021447607887936, ', objective function = ', array([ 499722.68337254]), 'error change  = ', array([ 1900.55836444]))
# ('m = ', -0.032914949988529077, ', c = ', 67.892647382177955, ', objective function = ', array([ 497831.97103431]), 'error change  = ', array([ 1890.71233823]))
# ('m = ', -0.032849327911625079, ', c = ', 67.764271156175383, ', objective function = ', array([ 495951.04871593]), 'error change  = ', array([ 1880.92231839]))
# ('m = ', -0.032783921857179481, ', c = ', 67.636317534108102, ', objective function = ', array([ 494079.86075045]), 'error change  = ', array([ 1871.18796548]))
# ('m = ', -0.032718731114064183, ', c = ', 67.508785124798834, ', objective function = ', array([ 492218.35180827]), 'error change  = ', array([ 1861.50894218]))
# ('m = ', -0.032653754973492093, ', c = ', 67.381672541650033, ', objective function = ', array([ 490366.46689498]), 'error change  = ', array([ 1851.88491329]))
# ('m = ', -0.032588992729009357, ', c = ', 67.254978402628623, ', objective function = ', array([ 488524.15134924]), 'error change  = ', array([ 1842.31554574]))
# ('m = ', -0.03252444367648772, ', c = ', 67.128701330251104, ', objective function = ', array([ 486691.35084069]), 'error change  = ', array([ 1832.80050855]))
# ('m = ', -0.032460107114116787, ', c = ', 67.002839951568419, ', objective function = ', array([ 484868.0113679]), 'error change  = ', array([ 1823.33947279]))
# ('m = ', -0.032395982342396636, ', c = ', 66.877392898151456, ', objective function = ', array([ 483054.07925626]), 'error change  = ', array([ 1813.93211164]))
# ('m = ', -0.032332068664129875, ', c = ', 66.752358806075506, ', objective function = ', array([ 481249.50115593]), 'error change  = ', array([ 1804.57810032]))
# ('m = ', -0.032268365384414285, ', c = ', 66.627736315905977, ', objective function = ', array([ 479454.22403984]), 'error change  = ', array([ 1795.2771161]))
# ('m = ', -0.032204871810635229, ', c = ', 66.503524072683376, ', objective function = ', array([ 477668.19520159]), 'error change  = ', array([ 1786.02883825]))
# ('m = ', -0.032141587252458068, ', c = ', 66.379720725908655, ', objective function = ', array([ 475891.36225349]), 'error change  = ', array([ 1776.8329481]))
# ('m = ', -0.032078511021820681, ', c = ', 66.256324929528404, ', objective function = ', array([ 474123.67312454]), 'error change  = ', array([ 1767.68912895]))
# ('m = ', -0.032015642432926025, ', c = ', 66.133335341920414, ', objective function = ', array([ 472365.07605843]), 'error change  = ', array([ 1758.59706611]))
# ('m = ', -0.031952980802234604, ', c = ', 66.010750625878899, ', objective function = ', array([ 470615.51961158]), 'error change  = ', array([ 1749.55644685]))
# ('m = ', -0.031890525448457177, ', c = ', 65.888569448600251, ', objective function = ', array([ 468874.95265115]), 'error change  = ', array([ 1740.56696043]))
# ('m = ', -0.031828275692547099, ', c = ', 65.766790481668011, ', objective function = ', array([ 467143.32435311]), 'error change  = ', array([ 1731.62829803]))
# ('m = ', -0.03176623085769318, ', c = ', 65.645412401038968, ', objective function = ', array([ 465420.5842003]), 'error change  = ', array([ 1722.74015281]))
# ('m = ', -0.031704390269312245, ', c = ', 65.524433887028579, ', objective function = ', array([ 463706.68198049]), 'error change  = ', array([ 1713.90221981]))
# ('m = ', -0.031642753255041782, ', c = ', 65.403853624296502, ', objective function = ', array([ 462001.56778446]), 'error change  = ', array([ 1705.11419603]))
# ('m = ', -0.031581319144732611, ', c = ', 65.283670301832416, ', objective function = ', array([ 460305.19200412]), 'error change  = ', array([ 1696.37578034]))
# ('m = ', -0.03152008727044165, ', c = ', 65.16388261294172, ', objective function = ', array([ 458617.50533059]), 'error change  = ', array([ 1687.68667353]))
# ('m = ', -0.031459056966424634, ', c = ', 65.044489255231397, ', objective function = ', array([ 456938.45875236]), 'error change  = ', array([ 1679.04657823]))
# ('m = ', -0.03139822756912887, ', c = ', 64.925488930595762, ', objective function = ', array([ 455268.00355339]), 'error change  = ', array([ 1670.45519897]))
# ('m = ', -0.031337598417185968, ', c = ', 64.806880345202288, ', objective function = ', array([ 453606.09131126]), 'error change  = ', array([ 1661.91224213]))
# ('m = ', -0.031277168851404843, ', c = ', 64.688662209477869, ', objective function = ', array([ 451952.67389536]), 'error change  = ', array([ 1653.41741591]))
# ('m = ', -0.031216938214764275, ', c = ', 64.570833238094366, ', objective function = ', array([ 450307.70346499]), 'error change  = ', array([ 1644.97043036]))
# ('m = ', -0.031156905852406009, ', c = ', 64.453392149954979, ', objective function = ', array([ 448671.13246764]), 'error change  = ', array([ 1636.57099736]))
# ('m = ', -0.031097071111627447, ', c = ', 64.336337668180022, ', objective function = ', array([ 447042.91363707]), 'error change  = ', array([ 1628.21883056]))
# ('m = ', -0.031037433341874639, ', c = ', 64.219668520093222, ', objective function = ', array([ 445422.99999163]), 'error change  = ', array([ 1619.91364544]))
# ('m = ', -0.030977991894735296, ', c = ', 64.103383437208038, ', objective function = ', array([ 443811.34483238]), 'error change  = ', array([ 1611.65515925]))
# ('m = ', -0.030918746123931539, ', c = ', 63.987481155213423, ', objective function = ', array([ 442207.90174136]), 'error change  = ', array([ 1603.44309102]))
# ('m = ', -0.030859695385313017, ', c = ', 63.871960413960451, ', objective function = ', array([ 440612.62457983]), 'error change  = ', array([ 1595.27716153]))
# ('m = ', -0.030800839036849919, ', c = ', 63.75681995744857, ', objective function = ', array([ 439025.46748652]), 'error change  = ', array([ 1587.15709331]))
# ('m = ', -0.030742176438625882, ', c = ', 63.64205853381177, ', objective function = ', array([ 437446.38487587]), 'error change  = ', array([ 1579.08261065]))
# ('m = ', -0.030683706952831149, ', c = ', 63.527674895305189, ', objective function = ', array([ 435875.33143633]), 'error change  = ', array([ 1571.05343954]))
# ('m = ', -0.030625429943755528, ', c = ', 63.413667798291321, ', objective function = ', array([ 434312.26212863]), 'error change  = ', array([ 1563.0693077]))
# ('m = ', -0.030567344777781537, ', c = ', 63.300036003226644, ', objective function = ', array([ 432757.13218407]), 'error change  = ', array([ 1555.12994456]))
# ('m = ', -0.030509450823377547, ', c = ', 63.186778274648184, ', objective function = ', array([ 431209.89710283]), 'error change  = ', array([ 1547.23508124]))
# ('m = ', -0.030451747451090885, ', c = ', 63.073893381159962, ', objective function = ', array([ 429670.51265229]), 'error change  = ', array([ 1539.38445054]))
# ('m = ', -0.030394234033540891, ', c = ', 62.961380095419571, ', objective function = ', array([ 428138.93486535]), 'error change  = ', array([ 1531.57778693]))
# ('m = ', -0.030336909945412299, ', c = ', 62.849237194125045, ', objective function = ', array([ 426615.12003879]), 'error change  = ', array([ 1523.81482657]))
# ('m = ', -0.030279774563448301, ', c = ', 62.7374634580014, ', objective function = ', array([ 425099.02473157]), 'error change  = ', array([ 1516.09530722]))
# ('m = ', -0.030222827266443753, ', c = ', 62.626057671787329, ', objective function = ', array([ 423590.60576324]), 'error change  = ', array([ 1508.41896833]))
# ('m = ', -0.030166067435238551, ', c = ', 62.515018624222186, ', objective function = ', array([ 422089.82021227]), 'error change  = ', array([ 1500.78555096]))
# ('m = ', -0.03010949445271072, ', c = ', 62.404345108032551, ', objective function = ', array([ 420596.62541448]), 'error change  = ', array([ 1493.19479779]))
# ('m = ', -0.030053107703769864, ', c = ', 62.294035919919374, ', objective function = ', array([ 419110.97896137]), 'error change  = ', array([ 1485.64645311]))
# ('m = ', -0.029996906575350337, ', c = ', 62.184089860544567, ', objective function = ', array([ 417632.83869856]), 'error change  = ', array([ 1478.14026281]))
# ('m = ', -0.029940890456404762, ', c = ', 62.074505734518439, ', objective function = ', array([ 416162.16272419]), 'error change  = ', array([ 1470.67597437]))
# ('m = ', -0.029885058737897197, ', c = ', 61.965282350386232, ', objective function = ', array([ 414698.90938733]), 'error change  = ', array([ 1463.25333686]))
# ('m = ', -0.029829410812796657, ', c = ', 61.856418520615485, ', objective function = ', array([ 413243.03728644]), 'error change  = ', array([ 1455.87210089]))
# ('m = ', -0.029773946076070437, ', c = ', 61.747913061582935, ', objective function = ', array([ 411794.50526778]), 'error change  = ', array([ 1448.53201866]))
# ('m = ', -0.029718663924677508, ', c = ', 61.639764793561646, ', objective function = ', array([ 410353.27242389]), 'error change  = ', array([ 1441.23284389]))
# ('m = ', -0.029663563757562031, ', c = ', 61.531972540708331, ', objective function = ', array([ 408919.29809202]), 'error change  = ', array([ 1433.97433187]))
# ('m = ', -0.029608644975646754, ', c = ', 61.424535131050376, ', objective function = ', array([ 407492.54185262]), 'error change  = ', array([ 1426.7562394]))
# ('m = ', -0.029553906981826663, ', c = ', 61.317451396473452, ', objective function = ', array([ 406072.96352782]), 'error change  = ', array([ 1419.5783248]))
# ('m = ', -0.029499349180962232, ', c = ', 61.210720172708278, ', objective function = ', array([ 404660.52317992]), 'error change  = ', array([ 1412.4403479]))
# ('m = ', -0.029444970979873138, ', c = ', 61.104340299318437, ', objective function = ', array([ 403255.18110989]), 'error change  = ', array([ 1405.34207003]))
# ('m = ', -0.029390771787331738, ', c = ', 60.998310619687437, ', objective function = ', array([ 401856.89785587]), 'error change  = ', array([ 1398.28325402]))
# ('m = ', -0.029336751014056663, ', c = ', 60.892629981006358, ', objective function = ', array([ 400465.6341917]), 'error change  = ', array([ 1391.26366417]))
# ('m = ', -0.029282908072706448, ', c = ', 60.787297234261231, ', objective function = ', array([ 399081.35112544]), 'error change  = ', array([ 1384.28306626]))
# ('m = ', -0.029229242377873069, ', c = ', 60.682311234220521, ', objective function = ', array([ 397704.00989793]), 'error change  = ', array([ 1377.34122751]))
# ('m = ', -0.029175753346075632, ', c = ', 60.577670839422723, ', objective function = ', array([ 396333.5719813]), 'error change  = ', array([ 1370.43791662]))
# ('m = ', -0.029122440395754023, ', c = ', 60.473374912163933, ', objective function = ', array([ 394969.99907758]), 'error change  = ', array([ 1363.57290373]))
# ('m = ', -0.029069302947262548, ', c = ', 60.369422318485434, ', objective function = ', array([ 393613.25311719]), 'error change  = ', array([ 1356.74596039]))
# ('m = ', -0.02901634042286369, ', c = ', 60.265811928161426, ', objective function = ', array([ 392263.2962576]), 'error change  = ', array([ 1349.95685959]))
# ('m = ', -0.028963552246721761, ', c = ', 60.162542614686743, ', objective function = ', array([ 390920.09088185]), 'error change  = ', array([ 1343.20537575]))
# ('m = ', -0.028910937844896685, ', c = ', 60.059613255264509, ', objective function = ', array([ 389583.59959718]), 'error change  = ', array([ 1336.49128467]))
# ('m = ', -0.028858496645337798, ', c = ', 59.957022730794115, ', objective function = ', array([ 388253.78523361]), 'error change  = ', array([ 1329.81436357]))
# ('m = ', -0.028806228077877496, ', c = ', 59.854769925858818, ', objective function = ', array([ 386930.61084256]), 'error change  = ', array([ 1323.17439105]))
# ('m = ', -0.028754131574225215, ', c = ', 59.752853728713866, ', objective function = ', array([ 385614.03969548]), 'error change  = ', array([ 1316.57114708]))
# ('m = ', -0.028702206567961065, ', c = ', 59.651273031274144, ', objective function = ', array([ 384304.03528246]), 'error change  = ', array([ 1310.00441302]))
# ('m = ', -0.028650452494529813, ', c = ', 59.550026729102349, ', objective function = ', array([ 383000.56131089]), 'error change  = ', array([ 1303.47397157]))
# ('m = ', -0.02859886879123472, ', c = ', 59.449113721396898, ', objective function = ', array([ 381703.58170408]), 'error change  = ', array([ 1296.97960681]))
# ('m = ', -0.028547454897231334, ', c = ', 59.348532910979912, ', objective function = ', array([ 380413.06059994]), 'error change  = ', array([ 1290.52110414]))
# ('m = ', -0.028496210253521493, ', c = ', 59.248283204285336, ', objective function = ', array([ 379128.96234964]), 'error change  = ', array([ 1284.09825031]))
# ('m = ', -0.028445134302947237, ', c = ', 59.1483635113471, ', objective function = ', array([ 377851.25151624]), 'error change  = ', array([ 1277.71083339]))
# ('m = ', -0.028394226490184658, ', c = ', 59.048772745787126, ', objective function = ', array([ 376579.89287345]), 'error change  = ', array([ 1271.35864279]))
# ('m = ', -0.028343486261737959, ', c = ', 58.94950982480362, ', objective function = ', array([ 375314.85140425]), 'error change  = ', array([ 1265.0414692]))
# ('m = ', -0.028292913065933435, ', c = ', 58.850573669159353, ', objective function = ', array([ 374056.09229962]), 'error change  = ', array([ 1258.75910463]))
# ('m = ', -0.028242506352913432, ', c = ', 58.751963203169858, ', objective function = ', array([ 372803.58095723]), 'error change  = ', array([ 1252.51134239]))
# ('m = ', -0.028192265574630334, ', c = ', 58.653677354691595, ', objective function = ', array([ 371557.28298017]), 'error change  = ', array([ 1246.29797706]))
# ('m = ', -0.028142190184840713, ', c = ', 58.555715055110568, ', objective function = ', array([ 370317.16417568]), 'error change  = ', array([ 1240.1188045]))
# ('m = ', -0.028092279639099299, ', c = ', 58.458075239330498, ', objective function = ', array([ 369083.19055383]), 'error change  = ', array([ 1233.97362185]))
# ('m = ', -0.028042533394753103, ', c = ', 58.360756845761394, ', objective function = ', array([ 367855.32832632]), 'error change  = ', array([ 1227.86222751]))
# ('m = ', -0.027992950910935493, ', c = ', 58.263758816307821, ', objective function = ', array([ 366633.5439052]), 'error change  = ', array([ 1221.78442112]))
# ('m = ', -0.027943531648560321, ', c = ', 58.167080096357587, ', objective function = ', array([ 365417.80390162]), 'error change  = ', array([ 1215.74000358]))
# ('m = ', -0.02789427507031611, ', c = ', 58.070719634770207, ', objective function = ', array([ 364208.07512459]), 'error change  = ', array([ 1209.72877703]))
# ('m = ', -0.027845180640660095, ', c = ', 57.974676383865372, ', objective function = ', array([ 363004.32457977]), 'error change  = ', array([ 1203.75054482]))
# ('m = ', -0.027796247825812519, ', c = ', 57.878949299411708, ', objective function = ', array([ 361806.51946824]), 'error change  = ', array([ 1197.80511153]))
# ('m = ', -0.027747476093750823, ', c = ', 57.783537340615439, ', objective function = ', array([ 360614.62718527]), 'error change  = ', array([ 1191.89228297]))
# ('m = ', -0.02769886491420372, ', c = ', 57.688439470108861, ', objective function = ', array([ 359428.61531914]), 'error change  = ', array([ 1186.01186614]))
# ('m = ', -0.027650413758645628, ', c = ', 57.593654653939275, ', objective function = ', array([ 358248.45164991]), 'error change  = ', array([ 1180.16366923]))
# ('m = ', -0.027602122100290755, ', c = ', 57.499181861557645, ', objective function = ', array([ 357074.10414827]), 'error change  = ', array([ 1174.34750164]))
# ('m = ', -0.027553989414087526, ', c = ', 57.40502006580747, ', objective function = ', array([ 355905.54097432]), 'error change  = ', array([ 1168.56317395]))
# ('m = ', -0.027506015176712691, ', c = ', 57.311168242913439, ', objective function = ', array([ 354742.73047642]), 'error change  = ', array([ 1162.8104979]))
# ('m = ', -0.027458198866565829, ', c = ', 57.217625372470593, ', objective function = ', array([ 353585.64118999]), 'error change  = ', array([ 1157.08928642]))
# ('m = ', -0.027410539963763528, ', c = ', 57.124390437432901, ', objective function = ', array([ 352434.2418364]), 'error change  = ', array([ 1151.39935359]))
# ('m = ', -0.027363037950133798, ', c = ', 57.031462424102436, ', objective function = ', array([ 351288.50132177]), 'error change  = ', array([ 1145.74051463]))
# ('m = ', -0.027315692309210469, ', c = ', 56.938840322118352, ', objective function = ', array([ 350148.38873583]), 'error change  = ', array([ 1140.11258594]))
# ('m = ', -0.027268502526227496, ', c = ', 56.846523124445739, ', objective function = ', array([ 349013.87335082]), 'error change  = ', array([ 1134.51538501]))
# ('m = ', -0.027221468088113394, ', c = ', 56.754509827364735, ', objective function = ', array([ 347884.92462031]), 'error change  = ', array([ 1128.94873051]))
# ('m = ', -0.027174588483485685, ', c = ', 56.662799430459728, ', objective function = ', array([ 346761.5121781]), 'error change  = ', array([ 1123.41244221]))
# ('m = ', -0.027127863202645309, ', c = ', 56.571390936608289, ', objective function = ', array([ 345643.6058371]), 'error change  = ', array([ 1117.90634099]))
# ('m = ', -0.027081291737571143, ', c = ', 56.480283351970606, ', objective function = ', array([ 344531.17558824]), 'error change  = ', array([ 1112.43024887]))
# ('m = ', -0.02703487358191432, ', c = ', 56.389475685978269, ', objective function = ', array([ 343424.19159931]), 'error change  = ', array([ 1106.98398893]))
# ('m = ', -0.026988608230992955, ', c = ', 56.298966951323941, ', objective function = ', array([ 342322.62421394]), 'error change  = ', array([ 1101.56738537]))
# ('m = ', -0.026942495181786489, ', c = ', 56.208756163950412, ', objective function = ', array([ 341226.44395044]), 'error change  = ', array([ 1096.1802635]))
# ('m = ', -0.026896533932930188, ', c = ', 56.118842343039674, ', objective function = ', array([ 340135.62150078]), 'error change  = ', array([ 1090.82244966]))
# ('m = ', -0.026850723984709883, ', c = ', 56.029224511002759, ', objective function = ', array([ 339050.12772946]), 'error change  = ', array([ 1085.49377132]))
# ('m = ', -0.026805064839056321, ', c = ', 55.939901693468649, ', objective function = ', array([ 337969.93367248]), 'error change  = ', array([ 1080.19405697]))
# ('m = ', -0.02675955599953999, ', c = ', 55.85087291927411, ', objective function = ', array([ 336895.01053628]), 'error change  = ', array([ 1074.9231362]))
# ('m = ', -0.026714196971365428, ', c = ', 55.762137220452615, ', objective function = ', array([ 335825.32969665]), 'error change  = ', array([ 1069.68083963]))
# ('m = ', -0.026668987261366076, ', c = ', 55.673693632224243, ', objective function = ', array([ 334760.86269771]), 'error change  = ', array([ 1064.46699894]))
# ('m = ', -0.026623926377998874, ', c = ', 55.585541192985154, ', objective function = ', array([ 333701.58125088]), 'error change  = ', array([ 1059.28144683]))
# ('m = ', -0.026579013831338812, ', c = ', 55.497678944296837, ', objective function = ', array([ 332647.4572338]), 'error change  = ', array([ 1054.12401708]))
# ('m = ', -0.026534249133073701, ', c = ', 55.410105930875979, ', objective function = ', array([ 331598.46268936]), 'error change  = ', array([ 1048.99454444]))
# ('m = ', -0.026489631796498814, ', c = ', 55.322821200583924, ', objective function = ', array([ 330554.56982462]), 'error change  = ', array([ 1043.89286474]))
# ('m = ', -0.026445161336511661, ', c = ', 55.235823804416469, ', objective function = ', array([ 329515.75100985]), 'error change  = ', array([ 1038.81881477]))
# ('m = ', -0.026400837269606636, ', c = ', 55.149112796493363, ', objective function = ', array([ 328481.97877749]), 'error change  = ', array([ 1033.77223236]))
# ('m = ', -0.026356659113869762, ', c = ', 55.062687234048134, ', objective function = ', array([ 327453.22582114]), 'error change  = ', array([ 1028.75295635]))
# ('m = ', -0.026312626388973588, ', c = ', 54.976546177417916, ', objective function = ', array([ 326429.4649946]), 'error change  = ', array([ 1023.76082654]))
# ('m = ', -0.026268738616171756, ', c = ', 54.890688690032988, ', objective function = ', array([ 325410.66931084]), 'error change  = ', array([ 1018.79568376]))
# ('m = ', -0.026224995318293965, ', c = ', 54.805113838406896, ', objective function = ', array([ 324396.81194104]), 'error change  = ', array([ 1013.8573698]))
# ('m = ', -0.026181396019740691, ', c = ', 54.719820692126007, ', objective function = ', array([ 323387.86621363]), 'error change  = ', array([ 1008.94572742]))
# ('m = ', -0.02613794024647801, ', c = ', 54.634808323839522, ', objective function = ', array([ 322383.80561326]), 'error change  = ', array([ 1004.06060036]))
# ('m = ', -0.026094627526032567, ', c = ', 54.550075809249584, ', objective function = ', array([ 321384.60377992]), 'error change  = ', array([ 999.20183335]))
# ('m = ', -0.026051457387486252, ', c = ', 54.465622227100823, ', objective function = ', array([ 320390.23450789]), 'error change  = ', array([ 994.36927202]))
# ('m = ', -0.026008429361471252, ', c = ', 54.381446659170741, ', objective function = ', array([ 319400.67174488]), 'error change  = ', array([ 989.56276302]))
# ('m = ', -0.025965542980164874, ', c = ', 54.297548190259533, ', objective function = ', array([ 318415.88959099]), 'error change  = ', array([ 984.78215388]))
# ('m = ', -0.025922797777284418, ', c = ', 54.213925908180059, ', objective function = ', array([ 317435.86229787]), 'error change  = ', array([ 980.02729312]))
# ('m = ', -0.025880193288082103, ', c = ', 54.130578903747974, ', objective function = ', array([ 316460.56426769]), 'error change  = ', array([ 975.29803018]))
# ('m = ', -0.02583772904934022, ', c = ', 54.047506270772189, ', objective function = ', array([ 315489.97005228]), 'error change  = ', array([ 970.59421541]))
# ('m = ', -0.025795404599365742, ', c = ', 53.964707106044344, ', objective function = ', array([ 314524.05435216]), 'error change  = ', array([ 965.91570011]))
# ('m = ', -0.025753219477985666, ', c = ', 53.882180509329693, ', objective function = ', array([ 313562.79201569]), 'error change  = ', array([ 961.26233647]))
# ('m = ', -0.025711173226541727, ', c = ', 53.799925583356767, ', objective function = ', array([ 312606.15803807]), 'error change  = ', array([ 956.63397762]))
# ('m = ', -0.025669265387885561, ', c = ', 53.71794143380793, ', objective function = ', array([ 311654.12756051]), 'error change  = ', array([ 952.03047756]))
# ('m = ', -0.025627495506373704, ', c = ', 53.636227169309542, ', objective function = ', array([ 310706.67586929]), 'error change  = ', array([ 947.45169122]))
# ('m = ', -0.02558586312786262, ', c = ', 53.554781901422302, ', objective function = ', array([ 309763.77839488]), 'error change  = ', array([ 942.89747441]))
# ('m = ', -0.025544367799703812, ', c = ', 53.473604744631629, ', objective function = ', array([ 308825.41071106]), 'error change  = ', array([ 938.36768382]))
# ('m = ', -0.025503009070738828, ', c = ', 53.392694816337908, ', objective function = ', array([ 307891.54853403]), 'error change  = ', array([ 933.86217704]))
# ('m = ', -0.025461786491294394, ', c = ', 53.312051236846983, ', objective function = ', array([ 306962.16772151]), 'error change  = ', array([ 929.38081251]))
# ('m = ', -0.025420699613177552, ', c = ', 53.231673129360622, ', objective function = ', array([ 306037.24427193]), 'error change  = ', array([ 924.92344958]))
# ('m = ', -0.025379747989670683, ', c = ', 53.151559619966832, ', objective function = ', array([ 305116.75432349]), 'error change  = ', array([ 920.48994844]))
# ('m = ', -0.025338931175526821, ', c = ', 53.071709837630571, ', objective function = ', array([ 304200.67415336]), 'error change  = ', array([ 916.08017013]))
# ('m = ', -0.025298248726964692, ', c = ', 52.992122914184215, ', objective function = ', array([ 303288.9801768]), 'error change  = ', array([ 911.69397656]))
# ('m = ', -0.025257700201663878, ', c = ', 52.912797984317955, ', objective function = ', array([ 302381.64894631]), 'error change  = ', array([ 907.33123049]))
# ('m = ', -0.025217285158760056, ', c = ', 52.833734185570556, ', objective function = ', array([ 301478.65715078]), 'error change  = ', array([ 902.99179552]))
# ('m = ', -0.025177003158840163, ', c = ', 52.754930658319843, ', objective function = ', array([ 300579.98161469]), 'error change  = ', array([ 898.6755361]))
# ('m = ', -0.025136853763937744, ', c = ', 52.676386545773717, ', objective function = ', array([ 299685.59929722]), 'error change  = ', array([ 894.38231747]))
# ('m = ', -0.025096836537527978, ', c = ', 52.598100993960237, ', objective function = ', array([ 298795.48729145]), 'error change  = ', array([ 890.11200576]))
# ('m = ', -0.025056951044523157, ', c = ', 52.520073151718954, ', objective function = ', array([ 297909.62282358]), 'error change  = ', array([ 885.86446787]))
# ('m = ', -0.025017196851267746, ', c = ', 52.442302170691164, ', objective function = ', array([ 297027.98325203]), 'error change  = ', array([ 881.63957155]))
# ('m = ', -0.024977573525533821, ', c = ', 52.364787205310932, ', objective function = ', array([ 296150.54606668]), 'error change  = ', array([ 877.43718535]))
# ('m = ', -0.024938080636516299, ', c = ', 52.28752741279591, ', objective function = ', array([ 295277.28888805]), 'error change  = ', array([ 873.25717862]))
# ('m = ', -0.024898717754828326, ', c = ', 52.210521953138183, ', objective function = ', array([ 294408.18946653]), 'error change  = ', array([ 869.09942152]))
# ('m = ', -0.024859484452496455, ', c = ', 52.133769989094858, ', objective function = ', array([ 293543.22568152]), 'error change  = ', array([ 864.96378501]))
# ('m = ', -0.024820380302956167, ', c = ', 52.057270686179393, ', objective function = ', array([ 292682.37554068]), 'error change  = ', array([ 860.85014084]))
# ('m = ', -0.024781404881047155, ', c = ', 51.981023212652204, ', objective function = ', array([ 291825.61717915]), 'error change  = ', array([ 856.75836153]))
# ('m = ', -0.024742557763008637, ', c = ', 51.905026739511669, ', objective function = ', array([ 290972.92885875]), 'error change  = ', array([ 852.6883204]))
# ('m = ', -0.024703838526474918, ', c = ', 51.82928044048532, ', objective function = ', array([ 290124.2889672]), 'error change  = ', array([ 848.63989155]))
# ('m = ', -0.024665246750470597, ', c = ', 51.753783492020574, ', objective function = ', array([ 289279.67601737]), 'error change  = ', array([ 844.61294983]))
# ('m = ', -0.024626782015406187, ', c = ', 51.678535073276045, ', objective function = ', array([ 288439.06864648]), 'error change  = ', array([ 840.60737089]))
# ('m = ', -0.024588443903073371, ', c = ', 51.60353436611237, ', objective function = ', array([ 287602.44561538]), 'error change  = ', array([ 836.6230311]))
# ('m = ', -0.024550231996640574, ', c = ', 51.528780555083479, ', objective function = ', array([ 286769.78580776]), 'error change  = ', array([ 832.65980762]))
# ('m = ', -0.024512145880648414, ', c = ', 51.454272827427701, ', objective function = ', array([ 285941.06822941]), 'error change  = ', array([ 828.71757835]))
# ('m = ', -0.024474185141005134, ', c = ', 51.38001037305888, ', objective function = ', array([ 285116.27200746]), 'error change  = ', array([ 824.79622195]))
# ('m = ', -0.024436349364982145, ', c = ', 51.305992384557612, ', objective function = ', array([ 284295.37638967]), 'error change  = ', array([ 820.89561779]))
# ('m = ', -0.024398638141209506, ', c = ', 51.232218057162399, ', objective function = ', array([ 283478.36074366]), 'error change  = ', array([ 817.01564602]))
# ('m = ', -0.024361051059671505, ', c = ', 51.158686588761022, ', objective function = ', array([ 282665.20455617]), 'error change  = ', array([ 813.15618749]))
# ('m = ', -0.024323587711702205, ', c = ', 51.085397179881824, ', objective function = ', array([ 281855.88743237]), 'error change  = ', array([ 809.3171238]))
# ('m = ', -0.024286247689980892, ', c = ', 51.012349033684799, ', objective function = ', array([ 281050.38909511]), 'error change  = ', array([ 805.49833726]))
# ('m = ', -0.0242490305885277, ', c = ', 50.939541355953025, ', objective function = ', array([ 280248.68938419]), 'error change  = ', array([ 801.69971092]))
# ('m = ', -0.024211936002699292, ', c = ', 50.866973355084276, ', objective function = ', array([ 279450.76825567]), 'error change  = ', array([ 797.92112852]))
# ('m = ', -0.024174963529184353, ', c = ', 50.794644242082079, ', objective function = ', array([ 278656.60578115]), 'error change  = ', array([ 794.16247452]))
# ('m = ', -0.024138112765999205, ', c = ', 50.722553230547284, ', objective function = ', array([ 277866.18214705]), 'error change  = ', array([ 790.4236341]))
# ('m = ', -0.024101383312483529, ', c = ', 50.650699536669578, ', objective function = ', array([ 277079.47765394]), 'error change  = ', array([ 786.70449312]))
# ('m = ', -0.024064774769295888, ', c = ', 50.579082379218789, ', objective function = ', array([ 276296.47271579]), 'error change  = ', array([ 783.00493814]))
# ('m = ', -0.024028286738409468, ', c = ', 50.507700979536551, ', objective function = ', array([ 275517.14785935]), 'error change  = ', array([ 779.32485644]))
# ('m = ', -0.023991918823107729, ', c = ', 50.436554561527736, ', objective function = ', array([ 274741.4837234]), 'error change  = ', array([ 775.66413595]))
# ('m = ', -0.023955670627980062, ', c = ', 50.365642351652056, ', objective function = ', array([ 273969.46105808]), 'error change  = ', array([ 772.02266532]))
# ('m = ', -0.023919541758917535, ', c = ', 50.294963578915663, ', objective function = ', array([ 273201.06072424]), 'error change  = ', array([ 768.40033384]))
# ('m = ', -0.023883531823108633, ', c = ', 50.224517474862836, ', objective function = ', array([ 272436.26369273]), 'error change  = ', array([ 764.79703151]))
# ('m = ', -0.023847640429034919, ', c = ', 50.154303273567521, ', objective function = ', array([ 271675.05104374]), 'error change  = ', array([ 761.21264899]))
# ('m = ', -0.023811867186466759, ', c = ', 50.084320211624906, ', objective function = ', array([ 270917.40396615]), 'error change  = ', array([ 757.64707759]))
# ('m = ', -0.023776211706459126, ', c = ', 50.014567528143317, ', objective function = ', array([ 270163.30375683]), 'error change  = ', array([ 754.10020932]))
# ('m = ', -0.023740673601347437, ', c = ', 49.945044464735936, ', objective function = ', array([ 269412.73182002]), 'error change  = ', array([ 750.57193681]))
# ('m = ', -0.023705252484743221, ', c = ', 49.87575026551243, ', objective function = ', array([ 268665.66966666]), 'error change  = ', array([ 747.06215337]))
# ('m = ', -0.02366994797152995, ', c = ', 49.806684177070757, ', objective function = ', array([ 267922.09891372]), 'error change  = ', array([ 743.57075294]))
# ('m = ', -0.023634759677858889, ', c = ', 49.737845448489075, ', objective function = ', array([ 267182.00128359]), 'error change  = ', array([ 740.09763013]))
# ('m = ', -0.023599687221144937, ', c = ', 49.669233331317564, ', objective function = ', array([ 266445.35860343]), 'error change  = ', array([ 736.64268016]))
# ('m = ', -0.023564730220062374, ', c = ', 49.600847079570123, ', objective function = ', array([ 265712.1528045]), 'error change  = ', array([ 733.20579893]))
# ('m = ', -0.023529888294540797, ', c = ', 49.532685949716424, ', objective function = ', array([ 264982.36592156]), 'error change  = ', array([ 729.78688294]))
# ('m = ', -0.023495161065760953, ', c = ', 49.464749200673793, ', objective function = ', array([ 264255.98009222]), 'error change  = ', array([ 726.38582933]))
# ('m = ', -0.02346054815615067, ', c = ', 49.397036093799152, ', objective function = ', array([ 263532.97755635]), 'error change  = ', array([ 723.00253587]))
# ('m = ', -0.023426049189380661, ', c = ', 49.32954589288093, ', objective function = ', array([ 262813.34065541]), 'error change  = ', array([ 719.63690094]))
# ('m = ', -0.023391663790360485, ', c = ', 49.262277864131093, ', objective function = ', array([ 262097.05183185]), 'error change  = ', array([ 716.28882356]))
# ('m = ', -0.023357391585234498, ', c = ', 49.195231276177211, ', objective function = ', array([ 261384.0936285]), 'error change  = ', array([ 712.95820335]))
# ('m = ', -0.023323232201377764, ', c = ', 49.128405400054525, ', objective function = ', array([ 260674.44868797]), 'error change  = ', array([ 709.64494053]))
# ('m = ', -0.023289185267391987, ', c = ', 49.061799509197904, ', objective function = ', array([ 259968.09975203]), 'error change  = ', array([ 706.34893594]))
# ('m = ', -0.02325525041310145, ', c = ', 48.995412879433971, ', objective function = ', array([ 259265.029661]), 'error change  = ', array([ 703.07009103]))
# ('m = ', -0.023221427269549046, ', c = ', 48.929244788973307, ', objective function = ', array([ 258565.22135316]), 'error change  = ', array([ 699.80830784]))
# ('m = ', -0.023187715468992301, ', c = ', 48.863294518402668, ', objective function = ', array([ 257868.65786418]), 'error change  = ', array([ 696.56348899]))
# ('m = ', -0.023154114644899231, ', c = ', 48.797561350676879, ', objective function = ', array([ 257175.32232646]), 'error change  = ', array([ 693.33553772]))
# ('m = ', -0.02312062443194449, ', c = ', 48.732044571111345, ', objective function = ', array([ 256485.19796863]), 'error change  = ', array([ 690.12435783]))
# ('m = ', -0.023087244466005297, ', c = ', 48.666743467374012, ', objective function = ', array([ 255798.26811489]), 'error change  = ', array([ 686.92985373]))
# ('m = ', -0.023053974384157631, ', c = ', 48.601657329477952, ', objective function = ', array([ 255114.5161845]), 'error change  = ', array([ 683.7519304]))
# ('m = ', -0.023020813824672116, ', c = ', 48.536785449773326, ', objective function = ', array([ 254433.92569112]), 'error change  = ', array([ 680.59049338]))
# ('m = ', -0.0229877624270102, ', c = ', 48.472127122939902, ', objective function = ', array([ 253756.48024231]), 'error change  = ', array([ 677.44544881]))
# ('m = ', -0.022954819831820183, ', c = ', 48.407681645979288, ', objective function = ', array([ 253082.16353894]), 'error change  = ', array([ 674.31670337]))
# ('m = ', -0.02292198568093326, ', c = ', 48.343448318207159, ', objective function = ', array([ 252410.9593746]), 'error change  = ', array([ 671.20416434]))
# ('m = ', -0.022889259617359783, ', c = ', 48.279426441246024, ', objective function = ', array([ 251742.85163506]), 'error change  = ', array([ 668.10773954]))
# ('m = ', -0.022856641285285244, ', c = ', 48.215615319017225, ', objective function = ', array([ 251077.82429772]), 'error change  = ', array([ 665.02733734]))
# ('m = ', -0.022824130330066441, ', c = ', 48.152014257733626, ', objective function = ', array([ 250415.86143102]), 'error change  = ', array([ 661.9628667]))
# ('m = ', -0.022791726398227598, ', c = ', 48.088622565891875, ', objective function = ', array([ 249756.94719393]), 'error change  = ', array([ 658.91423709]))
# ('m = ', -0.022759429137456627, ', c = ', 48.025439554265098, ', objective function = ', array([ 249101.06583538]), 'error change  = ', array([ 655.88135855]))
# ('m = ', -0.022727238196601194, ', c = ', 47.962464535895336, ', objective function = ', array([ 248448.2016937]), 'error change  = ', array([ 652.86414168]))
# ('m = ', -0.022695153225664892, ', c = ', 47.899696826085858, ', objective function = ', array([ 247798.33919611]), 'error change  = ', array([ 649.86249758]))
# ...
# ('m = ', -0.012980651206087693, ', c = ', 28.895252504824096, ', objective function = ', array([ 90175.02665406]), 'error change  = ', array([ 0.00013952]))
# ('m = ', -0.012980651194698736, ', c = ', 28.895252482543921, ', objective function = ', array([ 90175.026515]), 'error change  = ', array([ 0.00013906]))
# ('m = ', -0.012980651183347253, ', c = ', 28.895252460337058, ', objective function = ', array([ 90175.0263764]), 'error change  = ', array([ 0.0001386]))
# ('m = ', -0.012980651172033147, ', c = ', 28.895252438203315, ', objective function = ', array([ 90175.02623826]), 'error change  = ', array([ 0.00013814]))
# ('m = ', -0.01298065116075629, ', c = ', 28.895252416142441, ', objective function = ', array([ 90175.02610057]), 'error change  = ', array([ 0.00013769]))
# ('m = ', -0.012980651149516574, ', c = ', 28.89525239415423, ', objective function = ', array([ 90175.02596333]), 'error change  = ', array([ 0.00013724]))
# ('m = ', -0.01298065113831386, ', c = ', 28.895252372238399, ', objective function = ', array([ 90175.02582655]), 'error change  = ', array([ 0.00013678]))
# ('m = ', -0.01298065112714801, ', c = ', 28.895252350394692, ', objective function = ', array([ 90175.02569021]), 'error change  = ', array([ 0.00013633]))
# ('m = ', -0.012980651116018914, ', c = ', 28.895252328622874, ', objective function = ', array([ 90175.02555433]), 'error change  = ', array([ 0.00013589]))
# ('m = ', -0.012980651104926456, ', c = ', 28.895252306922739, ', objective function = ', array([ 90175.02541889]), 'error change  = ', array([ 0.00013544]))
# ('m = ', -0.01298065109387052, ', c = ', 28.895252285294056, ', objective function = ', array([ 90175.02528389]), 'error change  = ', array([ 0.00013499]))
# ('m = ', -0.012980651082850965, ', c = ', 28.895252263736545, ', objective function = ', array([ 90175.02514935]), 'error change  = ', array([ 0.00013455]))
# ('m = ', -0.012980651071867692, ', c = ', 28.89525224225001, ', objective function = ', array([ 90175.02501524]), 'error change  = ', array([ 0.00013411]))
# ('m = ', -0.012980651060920577, ', c = ', 28.895252220834202, ', objective function = ', array([ 90175.02488158]), 'error change  = ', array([ 0.00013366]))
# ('m = ', -0.012980651050009491, ', c = ', 28.895252199488887, ', objective function = ', array([ 90175.02474835]), 'error change  = ', array([ 0.00013322]))
# ('m = ', -0.012980651039134336, ', c = ', 28.895252178213859, ', objective function = ', array([ 90175.02461557]), 'error change  = ', array([ 0.00013279]))
# ('m = ', -0.01298065102829497, ', c = ', 28.895252157008848, ', objective function = ', array([ 90175.02448322]), 'error change  = ', array([ 0.00013235]))
# ('m = ', -0.012980651017491292, ', c = ', 28.895252135873655, ', objective function = ', array([ 90175.02435131]), 'error change  = ', array([ 0.00013191]))
# ('m = ', -0.012980651006723172, ', c = ', 28.89525211480802, ', objective function = ', array([ 90175.02421983]), 'error change  = ', array([ 0.00013148]))
# ('m = ', -0.012980650995990503, ', c = ', 28.895252093811745, ', objective function = ', array([ 90175.02408878]), 'error change  = ', array([ 0.00013105]))
# ('m = ', -0.012980650985293184, ', c = ', 28.895252072884617, ', objective function = ', array([ 90175.02395817]), 'error change  = ', array([ 0.00013061]))
# ('m = ', -0.012980650974631065, ', c = ', 28.895252052026354, ', objective function = ', array([ 90175.02382798]), 'error change  = ', array([ 0.00013018]))
# ('m = ', -0.01298065096400404, ', c = ', 28.89525203123674, ', objective function = ', array([ 90175.02369823]), 'error change  = ', array([ 0.00012976]))
# ('m = ', -0.012980650953412, ', c = ', 28.895252010515577, ', objective function = ', array([ 90175.0235689]), 'error change  = ', array([ 0.00012933]))
# ('m = ', -0.01298065094285483, ', c = ', 28.895251989862622, ', objective function = ', array([ 90175.02344]), 'error change  = ', array([ 0.0001289]))
# ('m = ', -0.012980650932332419, ', c = ', 28.89525196927767, ', objective function = ', array([ 90175.02331152]), 'error change  = ', array([ 0.00012848]))
# ('m = ', -0.01298065092184464, ', c = ', 28.895251948760468, ', objective function = ', array([ 90175.02318346]), 'error change  = ', array([ 0.00012806]))
# ('m = ', -0.012980650911391382, ', c = ', 28.895251928310799, ', objective function = ', array([ 90175.02305583]), 'error change  = ', array([ 0.00012763]))
# ('m = ', -0.012980650900972539, ', c = ', 28.895251907928451, ', objective function = ', array([ 90175.02292861]), 'error change  = ', array([ 0.00012721]))
# ('m = ', -0.012980650890587996, ', c = ', 28.895251887613206, ', objective function = ', array([ 90175.02280182]), 'error change  = ', array([ 0.0001268]))
# ('m = ', -0.012980650880237648, ', c = ', 28.895251867364863, ', objective function = ', array([ 90175.02267544]), 'error change  = ', array([ 0.00012638]))
# ('m = ', -0.012980650869921357, ', c = ', 28.89525184718314, ', objective function = ', array([ 90175.02254948]), 'error change  = ', array([ 0.00012596]))
# ('m = ', -0.012980650859639026, ', c = ', 28.895251827067856, ', objective function = ', array([ 90175.02242393]), 'error change  = ', array([ 0.00012555]))
# ('m = ', -0.012980650849390544, ', c = ', 28.895251807018784, ', objective function = ', array([ 90175.0222988]), 'error change  = ', array([ 0.00012513]))
# ('m = ', -0.012980650839175803, ', c = ', 28.895251787035725, ', objective function = ', array([ 90175.02217408]), 'error change  = ', array([ 0.00012472]))
# ('m = ', -0.012980650828994692, ', c = ', 28.895251767118456, ', objective function = ', array([ 90175.02204977]), 'error change  = ', array([ 0.00012431]))
# ('m = ', -0.012980650818847084, ', c = ', 28.895251747266727, ', objective function = ', array([ 90175.02192586]), 'error change  = ', array([ 0.0001239]))
# ('m = ', -0.012980650808732895, ', c = ', 28.895251727480375, ', objective function = ', array([ 90175.02180237]), 'error change  = ', array([ 0.00012349]))
# ('m = ', -0.012980650798651999, ', c = ', 28.895251707759162, ', objective function = ', array([ 90175.02167928]), 'error change  = ', array([ 0.00012309]))
# ('m = ', -0.012980650788604296, ', c = ', 28.895251688102874, ', objective function = ', array([ 90175.0215566]), 'error change  = ', array([ 0.00012268]))
# ('m = ', -0.012980650778589654, ', c = ', 28.895251668511264, ', objective function = ', array([ 90175.02143432]), 'error change  = ', array([ 0.00012228]))
# ('m = ', -0.012980650768607983, ', c = ', 28.895251648984161, ', objective function = ', array([ 90175.02131245]), 'error change  = ', array([ 0.00012188]))
# ('m = ', -0.012980650758659168, ', c = ', 28.895251629521326, ', objective function = ', array([ 90175.02119097]), 'error change  = ', array([ 0.00012147]))
# ('m = ', -0.012980650748743114, ', c = ', 28.895251610122589, ', objective function = ', array([ 90175.0210699]), 'error change  = ', array([ 0.00012107]))
# ('m = ', -0.012980650738859692, ', c = ', 28.895251590787691, ', objective function = ', array([ 90175.02094922]), 'error change  = ', array([ 0.00012068]))
# ('m = ', -0.012980650729008824, ', c = ', 28.895251571516475, ', objective function = ', array([ 90175.02082894]), 'error change  = ', array([ 0.00012028]))
# ('m = ', -0.012980650719190386, ', c = ', 28.895251552308697, ', objective function = ', array([ 90175.02070906]), 'error change  = ', array([ 0.00011988]))
# ('m = ', -0.012980650709404256, ', c = ', 28.895251533164128, ', objective function = ', array([ 90175.02058957]), 'error change  = ', array([ 0.00011949]))
# ('m = ', -0.012980650699650337, ', c = ', 28.895251514082581, ', objective function = ', array([ 90175.02047047]), 'error change  = ', array([ 0.0001191]))
# ('m = ', -0.012980650689928519, ', c = ', 28.895251495063818, ', objective function = ', array([ 90175.02035177]), 'error change  = ', array([ 0.0001187]))
# ('m = ', -0.012980650680238709, ', c = ', 28.895251476107678, ', objective function = ', array([ 90175.02023346]), 'error change  = ', array([ 0.00011831]))
# ('m = ', -0.012980650670580804, ', c = ', 28.895251457213948, ', objective function = ', array([ 90175.02011554]), 'error change  = ', array([ 0.00011792]))
# ('m = ', -0.012980650660954681, ', c = ', 28.895251438382402, ', objective function = ', array([ 90175.019998]), 'error change  = ', array([ 0.00011753]))
# ('m = ', -0.012980650651360261, ', c = ', 28.895251419612872, ', objective function = ', array([ 90175.01988085]), 'error change  = ', array([ 0.00011715]))
# ('m = ', -0.012980650641797422, ', c = ', 28.895251400905128, ', objective function = ', array([ 90175.01976409]), 'error change  = ', array([ 0.00011676]))
# ('m = ', -0.012980650632266055, ', c = ', 28.895251382258948, ', objective function = ', array([ 90175.01964771]), 'error change  = ', array([ 0.00011638]))
# ('m = ', -0.012980650622766071, ', c = ', 28.895251363674166, ', objective function = ', array([ 90175.01953172]), 'error change  = ', array([ 0.00011599]))
# ('m = ', -0.012980650613297369, ', c = ', 28.895251345150584, ', objective function = ', array([ 90175.01941611]), 'error change  = ', array([ 0.00011561]))
# ('m = ', -0.012980650603859832, ', c = ', 28.895251326687962, ', objective function = ', array([ 90175.01930087]), 'error change  = ', array([ 0.00011523]))
# ('m = ', -0.012980650594453358, ', c = ', 28.89525130828611, ', objective function = ', array([ 90175.01918602]), 'error change  = ', array([ 0.00011485]))
# ('m = ', -0.012980650585077831, ', c = ', 28.895251289944802, ', objective function = ', array([ 90175.01907155]), 'error change  = ', array([ 0.00011447]))
# ('m = ', -0.01298065057573319, ', c = ', 28.895251271663913, ', objective function = ', array([ 90175.01895745]), 'error change  = ', array([ 0.0001141]))
# ('m = ', -0.012980650566419311, ', c = ', 28.895251253443206, ', objective function = ', array([ 90175.01884373]), 'error change  = ', array([ 0.00011372]))
# ('m = ', -0.012980650557136091, ', c = ', 28.895251235282476, ', objective function = ', array([ 90175.01873038]), 'error change  = ', array([ 0.00011335]))
# ('m = ', -0.012980650547883426, ', c = ', 28.895251217181524, ', objective function = ', array([ 90175.0186174]), 'error change  = ', array([ 0.00011297]))
# ('m = ', -0.012980650538661214, ', c = ', 28.895251199140144, ', objective function = ', array([ 90175.0185048]), 'error change  = ', array([ 0.0001126]))
# ('m = ', -0.012980650529469374, ', c = ', 28.895251181158187, ', objective function = ', array([ 90175.01839257]), 'error change  = ', array([ 0.00011223]))
# ('m = ', -0.012980650520307791, ', c = ', 28.895251163235411, ', objective function = ', array([ 90175.01828071]), 'error change  = ', array([ 0.00011186]))
# ('m = ', -0.012980650511176361, ', c = ', 28.895251145371635, ', objective function = ', array([ 90175.01816921]), 'error change  = ', array([ 0.00011149]))
# ('m = ', -0.012980650502074984, ', c = ', 28.895251127566645, ', objective function = ', array([ 90175.01805808]), 'error change  = ', array([ 0.00011113]))
# ('m = ', -0.012980650493003586, ', c = ', 28.895251109820297, ', objective function = ', array([ 90175.01794732]), 'error change  = ', array([ 0.00011076]))
# ('m = ', -0.012980650483962033, ', c = ', 28.895251092132344, ', objective function = ', array([ 90175.01783693]), 'error change  = ', array([ 0.0001104]))
# ('m = ', -0.012980650474950261, ', c = ', 28.895251074502649, ', objective function = ', array([ 90175.01772689]), 'error change  = ', array([ 0.00011003]))
# ('m = ', -0.012980650465968144, ', c = ', 28.895251056930963, ', objective function = ', array([ 90175.01761722]), 'error change  = ', array([ 0.00010967]))
# ('m = ', -0.012980650457015602, ', c = ', 28.89525103941714, ', objective function = ', array([ 90175.01750791]), 'error change  = ', array([ 0.00010931]))
# ('m = ', -0.012980650448092525, ', c = ', 28.895251021960956, ', objective function = ', array([ 90175.01739896]), 'error change  = ', array([ 0.00010895]))
# ('m = ', -0.012980650439198832, ', c = ', 28.895251004562262, ', objective function = ', array([ 90175.01729037]), 'error change  = ', array([ 0.00010859]))
# ('m = ', -0.012980650430334419, ', c = ', 28.895250987220834, ', objective function = ', array([ 90175.01718213]), 'error change  = ', array([ 0.00010823]))
# ('m = ', -0.01298065042149919, ', c = ', 28.895250969936509, ', objective function = ', array([ 90175.01707426]), 'error change  = ', array([ 0.00010788]))
# ('m = ', -0.012980650412693027, ', c = ', 28.895250952709048, ', objective function = ', array([ 90175.01696673]), 'error change  = ', array([ 0.00010752]))
# ('m = ', -0.012980650403915864, ', c = ', 28.895250935538314, ', objective function = ', array([ 90175.01685956]), 'error change  = ', array([ 0.00010717]))
# ('m = ', -0.012980650395167583, ', c = ', 28.895250918424086, ', objective function = ', array([ 90175.01675275]), 'error change  = ', array([ 0.00010682]))
# ('m = ', -0.012980650386448108, ', c = ', 28.895250901366211, ', objective function = ', array([ 90175.01664628]), 'error change  = ', array([ 0.00010646]))
# ('m = ', -0.012980650377757348, ', c = ', 28.895250884364508, ', objective function = ', array([ 90175.01654017]), 'error change  = ', array([ 0.00010611]))
# ('m = ', -0.012980650369095185, ', c = ', 28.895250867418753, ', objective function = ', array([ 90175.0164344]), 'error change  = ', array([ 0.00010576]))
# ('m = ', -0.012980650360461532, ', c = ', 28.895250850528765, ', objective function = ', array([ 90175.01632899]), 'error change  = ', array([ 0.00010542]))
# ('m = ', -0.012980650351856301, ', c = ', 28.89525083369438, ', objective function = ', array([ 90175.01622392]), 'error change  = ', array([ 0.00010507]))
# ('m = ', -0.012980650343279398, ', c = ', 28.895250816915425, ', objective function = ', array([ 90175.01611919]), 'error change  = ', array([ 0.00010472]))
# ('m = ', -0.012980650334730739, ', c = ', 28.895250800191711, ', objective function = ', array([ 90175.01601481]), 'error change  = ', array([ 0.00010438]))
# ('m = ', -0.012980650326210218, ', c = ', 28.89525078352305, ', objective function = ', array([ 90175.01591078]), 'error change  = ', array([ 0.00010404]))
# ('m = ', -0.012980650317717743, ', c = ', 28.89525076690925, ', objective function = ', array([ 90175.01580709]), 'error change  = ', array([ 0.00010369]))
# ('m = ', -0.012980650309253227, ', c = ', 28.895250750350151, ', objective function = ', array([ 90175.01570373]), 'error change  = ', array([ 0.00010335]))
# ('m = ', -0.012980650300816569, ', c = ', 28.895250733845547, ', objective function = ', array([ 90175.01560072]), 'error change  = ', array([ 0.00010301]))
# ('m = ', -0.012980650292407688, ', c = ', 28.895250717395289, ', objective function = ', array([ 90175.01549805]), 'error change  = ', array([ 0.00010267]))
# ('m = ', -0.012980650284026493, ', c = ', 28.895250700999188, ', objective function = ', array([ 90175.01539572]), 'error change  = ', array([ 0.00010233]))
# ('m = ', -0.012980650275672894, ', c = ', 28.895250684657071, ', objective function = ', array([ 90175.01529372]), 'error change  = ', array([ 0.000102]))
# ('m = ', -0.012980650267346789, ', c = ', 28.895250668368742, ', objective function = ', array([ 90175.01519206]), 'error change  = ', array([ 0.00010166]))
# ('m = ', -0.012980650259048081, ', c = ', 28.895250652134013, ', objective function = ', array([ 90175.01509073]), 'error change  = ', array([ 0.00010133]))
# ('m = ', -0.0129806502507767, ', c = ', 28.895250635952735, ', objective function = ', array([ 90175.01498974]), 'error change  = ', array([ 0.00010099]))
# ('m = ', -0.012980650242532546, ', c = ', 28.895250619824733, ', objective function = ', array([ 90175.01488908]), 'error change  = ', array([ 0.00010066]))
# ('m = ', -0.012980650234315534, ', c = ', 28.895250603749819, ', objective function = ', array([ 90175.01478875]), 'error change  = ', array([ 0.00010033]))
# ('m = ', -0.012980650226125571, ', c = ', 28.895250587727826, ', objective function = ', array([ 90175.01468875]), 'error change  = ', array([  9.99992481e-05]))

# %%
# results
print("m = ", m, ", c = ", c, ", objective function = ", error_new, "error change  = ", error)
f_test = m*x_test + c
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# ('m = ', -0.012980650226125571, ', c = ', 28.895250587727826, ', objective function = ', array([ 90175.01468875]), 'error change  = ', array([  9.99992481e-05]))

# %% [markdown]
# #### Question 2 Answer Text
#
# I believe we need more iterations to reach this solution is because we have a small sample size. With a small sample size, the c and m value will update at a slow rate. This will require the best fit to have many iterations before having a suitable line.

# %% [markdown]
# ### Multiple Input Solution with Linear Algebra
#
# You've now seen how slow it can be to perform a coordinate ascent on a system. Another approach to solving the system (which is not always possible, particularly in *non-linear* systems) is to go direct to the minimum. To do this we need to introduce *linear algebra*. We will represent all our errors and functions in the form of linear algebra.
#
# As we mentioned above, linear algebra is just a shorthand for performing lots of multiplications and additions simultaneously. What does it have to do with our system then? Well the first thing to note is that the linear function we were trying to fit has the following form:
# $$
#   f(x) = mx + c
# $$
# the classical form for a straight line. From a linear algebraic perspective we are looking for multiplications and additions. We are also looking to separate our parameters from our data. The data is the *givens* remember, in French the word is données literally translated means *givens* that's great, because we don't need to change the data, what we need to change are the parameters (or variables) of the model. In this function the data comes in through $x$, and the parameters are $m$ and $c$.
#
# What we'd like to create is a vector of parameters and a vector of data. Then we could represent the system with vectors that represent the data, and vectors that represent the parameters.
#
# We look to turn the multiplications and additions into a linear algebraic form, we have one multiplication ($m\times c$ and one addition ($mx + c$). But we can turn this into a inner product by writing it in the following way,
# $$
#   f(x) = m \times x + c \times 1
# $$
# in other words we've extracted the unit value, from the offset, $c$. We can think of this unit value like an extra item of data, because it is always given to us, and it is always set to 1 (unlike regular data, which is likely to vary!). We can therefore write each input data location, $\mathbf{x}$, as a vector
# $$
#   \mathbf{x} = \begin{bmatrix} 1 \\ x \end{bmatrix}
# $$
#
# Now we choose to also turn our parameters into a vector. The parameter vector will be defined to contain
# $$
#   \mathbf{w} = \begin{bmatrix} c \\ m \end{bmatrix}
# $$
# because if we now take the inner product between these to vectors we recover
# $$
#   \mathbf{x}\cdot\mathbf{w} = 1 \times c + x \times m = mx + c
# $$
# In `numpy` we can define this vector as follows:

# %%
# define the vector w
w = np.zeros(shape=(2,1))
w[0] = m
w[1] = c

# %% [markdown]
# This gives us the equivalence between original operation and an operation in vector space. Whilst the notation here isn't a lot shorter, the beauty is that we will be able to add as many features as we like and still keep the seame representation. In general, we are now moving to a system where each of our predictions is given by an inner product. When we want to represent a linear product in linear algebra, we tend to do it with the transpose operation, so since we have $\mathbf{a}\cdot\mathbf{b} = \mathbf{a}^\top \mathbf{b}$ we can write
# $$
#   f(\mathbf{x}_i) = \mathbf{x}_i^\top \mathbf{w}
# $$
# where we've assumed that each data point, $\mathbf{x}_i$, is now written by appending a 1 onto the original vector
# $$
#   \mathbf{x}_i = \begin{bmatrix} 1 \\ x_i \end{bmatrix}
# $$
#
# ### Design Matrix
#
# We can do this for the entire data set to form a [*design matrix*](http://en.wikipedia.org/wiki/Design_matrix) $\mathbf{X}$,
# $$
#   \mathbf{X} = \begin{bmatrix}
#     \mathbf{x}_1^\top \\
#     \mathbf{x}_2^\top \\
#     \vdots \\
#     \mathbf{x}_n^\top
#   \end{bmatrix} = \begin{bmatrix}
#     1 & x_1 \\
#     1 & x_2 \\
#     \vdots & \vdots \\
#     1 & x_n
#   \end{bmatrix}
# $$
# which in `numpy` can be done with the following commands:

# %%
X = np.hstack((np.ones_like(x), x))
print(X)
# Out:
# [[  1.00000000e+00   1.89600000e+03]
#  [  1.00000000e+00   1.90000000e+03]
#  [  1.00000000e+00   1.90400000e+03]
#  [  1.00000000e+00   1.90800000e+03]
#  [  1.00000000e+00   1.91200000e+03]
#  [  1.00000000e+00   1.92000000e+03]
#  [  1.00000000e+00   1.92400000e+03]
#  [  1.00000000e+00   1.92800000e+03]
#  [  1.00000000e+00   1.93200000e+03]
#  [  1.00000000e+00   1.93600000e+03]
#  [  1.00000000e+00   1.94800000e+03]
#  [  1.00000000e+00   1.95200000e+03]
#  [  1.00000000e+00   1.95600000e+03]
#  [  1.00000000e+00   1.96000000e+03]
#  [  1.00000000e+00   1.96400000e+03]
#  [  1.00000000e+00   1.96800000e+03]
#  [  1.00000000e+00   1.97200000e+03]
#  [  1.00000000e+00   1.97600000e+03]
#  [  1.00000000e+00   1.98000000e+03]
#  [  1.00000000e+00   1.98400000e+03]
#  [  1.00000000e+00   1.98800000e+03]
#  [  1.00000000e+00   1.99200000e+03]
#  [  1.00000000e+00   1.99600000e+03]
#  [  1.00000000e+00   2.00000000e+03]
#  [  1.00000000e+00   2.00400000e+03]
#  [  1.00000000e+00   2.00800000e+03]
#  [  1.00000000e+00   2.01200000e+03]]

# %% [markdown]
# ### Writing the Objective Function with Linear Algebra
#
# When we think of the objective function, we can think of it as the errors where the error is defined in a similar way to what it was in Legendre's day $y_i - f(\mathbf{x}_i)$, in statistics these errors are also sometimes called [*residuals*](http://en.wikipedia.org/wiki/Errors_and_residuals_in_statistics). So we can think as the objective and the prediction function as two separate parts, first we have,
# $$
#   E(\mathbf{w}) = \sum_{i=1}^n (y_i - f(\mathbf{x}_i; \mathbf{w}))^2
# $$
# where we've made the function $f(\cdot)$'s dependence on the parameters $\mathbf{w}$ explicit in this equation. Then we have the definition of the function itself,
# $$
#   f(\mathbf{x}_i; \mathbf{w}) = \mathbf{x}_i^\top \mathbf{w}
# $$
# Let's look again at these two equations and see if we can identify any inner products. The first equation is a sum of squares, which is promising. Any sum of squares can be represented by an inner product,
# $$
#   a = \sum_{i=1}^k b_i^2 = \mathbf{b}^\top \mathbf{b}
# $$
# so if we wish to represent $E(\mathbf{w})$ in this way, all we need to do is convert the sum operator to an inner product. We can get a vector from that sum operator by placing both $y_i$ and $f(\mathbf{x}_i; \mathbf{w})$ into vectors, which we do by defining
# $$
#   \mathbf{y} = \begin{bmatrix} y_1 \\ y_2 \\ \vdots \\ y_n \end{bmatrix}
# $$
# and defining
# $$
#   \mathbf{f}(\mathbf{x}; \mathbf{w}) = \begin{bmatrix} f(\mathbf{x}_1; \mathbf{w}) \\ f(\mathbf{x}_2; \mathbf{w}) \\ \vdots \\ f(\mathbf{x}_n; \mathbf{w}) \end{bmatrix}
# $$
# The second of these is actually a vector-valued function. This term may appear intimidating, but the idea is straightforward. A vector valued function is simply a vector whose elements are themselves defined as *functions*, i.e. it is a vector of functions, rather than a vector of scalars. The idea is so straightforward, that we are going to ignore it for the moment, and barely use it in the derivation. But it will reappear later when we introduce *basis functions*. So we will, for the moment, ignore the dependence of $\mathbf{f}$ on $\mathbf{w}$ and $\mathbf{X}$ and simply summarise it by a vector of numbers
# $$
#   \mathbf{f} = \begin{bmatrix} f_1 \\ f_2 \\ \vdots \\ f_n \end{bmatrix}
# $$
# This allows us to write our objective in the folowing, linear algebraic form,
# $$
#   E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top (\mathbf{y} - \mathbf{f})
# $$
# from the rules of inner products.
#
# But what of our matrix $\mathbf{X}$ of input data? At this point, we need to dust off [*matrix-vector multiplication*](http://en.wikipedia.org/wiki/Matrix_multiplication). Matrix multiplication is simply a convenient way of performing many inner products together, and it's exactly what we need to summarise the operation
# $$
#   f_i = \mathbf{x}_i^\top \mathbf{w}
# $$
# This operation tells us that each element of the vector $\mathbf{f}$ (our vector valued function) is given by an inner product between $\mathbf{x}_i$ and $\mathbf{w}$. In other words it is a series of inner products.
#
# Let's look at the definition of matrix multiplication, it takes the form
# $$
#   \mathbf{c} = \mathbf{B}\mathbf{a}
# $$
# where $\mathbf{c}$ might be a $k$ dimensional vector (which we can intepret as a $k\times 1$ dimensional matrix), and $\mathbf{B}$ is a $k\times k$ dimensional matrix and $\mathbf{a}$ is a $k$ dimensional vector ($k\times 1$ dimensional matrix). The result of this multiplication is of the form
# $$
#   \begin{bmatrix} c_1 \\ c_2 \\ \vdots \\ c_k \end{bmatrix}
#   = \begin{bmatrix}
#       b_{1,1} & b_{1,2} & \dots & b_{1,k} \\
#       b_{2,1} & b_{2,2} & \dots & b_{2,k} \\
#       \vdots & \vdots & \ddots & \vdots \\
#       b_{k,1} & b_{k,2} & \dots & b_{k,k}
#     \end{bmatrix}
#     \begin{bmatrix} a_1 \\ a_2 \\ \vdots \\ c_k \end{bmatrix}
#   = \begin{bmatrix}
#       b_{1,1}a_1 + b_{1,2}a_2 + \dots + b_{1,k}a_k \\
#       b_{2,1}a_1 + b_{2,2}a_2 + \dots + b_{2,k}a_k \\
#       \vdots \\
#       b_{k,1}a_1 + b_{k,2}a_2 + \dots + b_{k,k}a_k
#     \end{bmatrix}
# $$
# so we see that each element of the result, $\mathbf{c}$ is simply the inner product between each *row* of $\mathbf{B}$ and the vector $\mathbf{a}$.
#
# Because we have defined each element of $\mathbf{f}$ to be given by the inner product between each *row* of the design matrix and the vector $\mathbf{w}$ we now can write the full operation in one matrix multiplication,
# $$
#   \mathbf{f} = \mathbf{X}\mathbf{w}
# $$

# %%
# np.dot does matrix multiplication in python
f = np.dot(X, w)

# %% [markdown]
# Combining this result with our objective function,
# $$
#   E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top (\mathbf{y} - \mathbf{f})
# $$
# we find we have defined the *model* with two equations. One equation tells us the form of our predictive function and how it depends on its parameters, the other tells us the form of our objective function.

# %%
# matrix multiplication on a single vector is equivalent to a dot product
resid = (y-f)
E = np.dot(resid.T, resid)
print("Error function is:", E)
# Out:
# ('Error function is:', array([[  6.61507248e+11]]))

# %% [markdown]
# ### Assignment Question 3
#
# The prediction for our movie recommender system had the form
# $$
#   f_{i,j} = \mathbf{u}_i^\top \mathbf{v}_j
# $$
# and the objective function was then
# $$
#   E = \sum_{i,j} s_{i,j}(y_{i,j} - f_{i, j})^2
# $$
# Try writing this down in matrix and vector form. How many of the terms can you do? For each variable and parameter carefully think about whether it should be represented as a matrix or vector. Do as many of the terms as you can. Use $\LaTeX$ to give your answers and give the *dimensions* of any matrices you create.
#
# *10 points*
#
# #### Hint for Question 3
#
# \begin{align*}
#   E & = \sum_{i,j} s_{i,j}(y_{i,j} - f_{i,j})^2 \\
#     & = \sum_{i=1}^n \sum_{j=1}^m s_{i,j}(y_{i,j} - f_{i,j})^2 \\
#     & = \cdots \\
#     & = \sum_{i=1}^n \{\text{product of vectors, matrices}\} \\
#     & = \cdots \\
#     & = \{\text{product of vectors (of vectors), matrices}\} \\
# \end{align*}
# by defining suitable vectors and matrices.

# %% [markdown]
# #### Question 3 Answer
#
# Given $E$, translate it to matrix and vector form:
#
# \begin{align*}
#   E & = \sum_{i,j} s_{i,j}(y_{i,j} - f_{i,j})^2 \\
#     & = \sum_{i=1}^n \sum_{j=1}^m s_{i,j}(y_{i,j} - f_{i,j})^2 \\
#     & = \sum_{i=1}^n \sum_{j=1}^m s_{i,j}(y_{i,j}^2 -2 y_{i,j}f_{i,j}+ f_{i,j}^2) \\
# \end{align*}
#
# where $y_{i,j}^2 = \mathbf{y}^\top \mathbf{y}= y_{j,j}$, $f_{i,j}^2 = \mathbf{f}^\top \mathbf{f}= f_{j,j}$, and $f_{i,j}y_{i,j} = \mathbf{a}$ giving
#
# \begin{align*}
#   E & = \sum_{i,j} s_{i,j}(y_{j,j} +f_{j,j} - 2\mathbf{a})^2 \\
#     & = \mathbf{S}\mathbf{y} + \mathbf{S}\mathbf{f} - 2\mathbf{S}\mathbf{a} \\
# \end{align*}

# %% [markdown]
# ### Objective Optimisation
#
# Our *model* has now been defined with two equations, the prediction function and the objective function. Next we will use multivariate calculus to define an *algorithm* to fit the model. The separation between model and algorithm is important and is often overlooked. Our model contains a function that shows how it will be used for prediction, and a function that describes the objective function we need to optimise to obtain a good set of parameters.
#
# The linear regression model we have described is still the same as the one we fitted above with a coordinate ascent algorithm. We have only played with the notation to obtain the same model in a matrix and vector notation. However, we will now fit this model with a different algorithm, one that is much faster. It is such a widely used algorithm that from the end user's perspective it doesn't even look like an algorithm, it just appears to be a single operation (or function). However, underneath the computer calls an algorithm to find the solution. Further, the algorithm we obtain is very widely used, and because of this it turns out to be highly optimised.
#
# Once again we are going to try and find the stationary points of our objective by finding the *stationary points*. However, the stationary points of a multivariate function, are a little bit more complext to find. Once again we need to find the point at which the derivative is zero, but now we need to use *multivariate calculus* to find it. This involves learning a few additional rules of differentiation (that allow you to do the derivatives of a function with respect to vector), but in the end it makes things quite a bit easier. We define vectorial derivatives as follows,
# $$
#   \frac{\partial E(\mathbf{w})}{\partial \mathbf{w}}
#   = \begin{bmatrix} \frac{\partial E(\mathbf{w})}{\partial w_1} \\ \frac{\partial E(\mathbf{w})}{\partial w_2} \end{bmatrix}
# $$
# where $\frac{\partial E(\mathbf{w})}{\partial w_1}$ is the [partial derivative](http://en.wikipedia.org/wiki/Partial_derivative) of the error function with respect to $w_1$.
#
# Differentiation through multiplications and additions is relatively straightforward, and since linear algebra is just multiplication and addition, then its rules of diffentiation are quite straightforward too, but slightly more complex than regular derivatives.

# %% [markdown]
# ### Matrix Differentiation
#
# We will need two rules of differentiation. The first is diffentiation of an inner product. By remebering that the inner product is made up of multiplication and addition, we can hope that its derivative is quite straightforward, and so it proves to be. We can start by thinking about the definition of the inner product,
# $$
#   \mathbf{a}^\top \mathbf{z} = \sum_{i} a_i z_i,
# $$
# which if we were to take the derivative with respect to $z_k$ would simply return the gradient of the one term in the sum for which the derivative was non zero, that of $a_k$, so we know that
# $$
#   \frac{\partial}{\partial z_k} \mathbf{a}^\top \mathbf{z} = a_k
# $$
# and by our definition of multivariate derivatives we can simply stack all the partial derivatives of this form in a vector to obtain the result that
# $$
#   \frac{\partial}{\partial \mathbf{z}} \mathbf{a}^\top \mathbf{z} = \mathbf{a}
# $$
# The second rule that's required is differentiation of a 'matrix quadratic'. A scalar quadratic in $z$ with coefficient $c$ has the form $cz^2$. If $\mathbf{z}$ is a $k\times 1$ vector and $\mathbf{C}$ is a $k \times k$ *matrix* of coefficients then the matrix quadratic form is written as $\mathbf{z}^\top \mathbf{C}\mathbf{z}$, which is itself a *scalar* quantity, but it is a function of a *vector*.
#
# #### Matching Dimensions in Matrix Multiplications
#
# There's a trick for telling that it's a scalar result. When you are doing maths with matrices, it's always worth pausing to perform a quick sanity check on the dimensions. Matrix multplication only works when the dimensions match. To be precise, the 'inner' dimension of the matrix must match. What is the inner dimension. If we multiply two matrices $\mathbf{A}$ and $\mathbf{B}$, the first of which has $k$ rows and $\ell$ columns and the second of which has $p$ rows and $q$ columns, then we can check whether the multiplication works by writing the dimensionalities next to each other,
# $$
#   \mathbf{A}\mathbf{B} \rightarrow (k\times \underbrace{\ell)(p}_\text{inner dimensions} \times q) \rightarrow (k\times q)
# $$
# The inner dimensions are the two inside dimensions, $\ell$ and $p$. The multiplication will only work if $\ell = p$. The result of the multiplication will then be a $k\times q$ matrix: this dimensionality comes from the 'outer dimensions'. Note that matrix multiplication is not [*commutative*](http://en.wikipedia.org/wiki/Commutative_property). And if you change the order of the multiplication,
# $$
#   \mathbf{B}\mathbf{A} \rightarrow (\ell \times \underbrace{k)(q}_\text{inner dimensions} \times p) \rightarrow (\ell\times p)
# $$
# firstly it may no longer even work, because now the condition is that $k=q$, and secondly the result could be of a different dimensionality. An exception is if the matrices are square matrices (e.g. same number of rows as columns) and they are both *symmetric*. A symmetric matrix is one for which $\mathbf{A}=\mathbf{A}^\top$, or equivalently, $a_{i,j} = a_{j,i}$ for all $i$ and $j$.
#
# You will need to get used to working with matrices and vectors applying and developing new machine learning techniques. You should have come across them before, but you may not have used them as extensively as we will now do in this course. You should get used to using this trick to check your work and ensure you know what the dimension of an output matrix should be. For our matrix quadratic form, it turns out that we can see it as a special type of inner product.
# $$
#   \mathbf{z}^\top \mathbf{C}\mathbf{z} \rightarrow (1\times \underbrace{k)(k}_\text{inner dimensions} \times k) (k\times 1) \rightarrow \mathbf{b}^\top \mathbf{z}
# $$
# where $\mathbf{b} = \mathbf{C}\mathbf{z}$ so therefore the result is a scalar,
# $$
#   \mathbf{b}^\top \mathbf{z} \rightarrow (1\times \underbrace{k)(k}_\text{inner dimensions}\times 1) \rightarrow (1\times 1)
# $$
# where a $1\times 1$ matrix is recognised as a scalar.
#
# This implies that we should be able to differentiate this form, and indeed the rule for its differentiation is slightly more complex than the inner product, but still quite simple,
# $$
#   \frac{\partial}{\partial \mathbf{z}} \mathbf{z}^\top \mathbf{C}\mathbf{z} = (\mathbf{C} + \mathbf{C}^\top) \mathbf{z}
# $$
# Note that in the special case where $\mathbf{C}$ is symmetric then we have $\mathbf{C} = \mathbf{C}^\top$ and the derivative simplifies to
# $$
# \frac{\partial}{\partial \mathbf{z}} \mathbf{z}^\top \mathbf{C} \mathbf{z}= 2\mathbf{C}\mathbf{z}
# $$

# %% [markdown]
# ### Differentiating the Objective
#
# First, we need to compute the full objective by substituting our prediction function into the objective function to obtain the objective in terms of $\mathbf{w}$. Doing this we obtain
# $$
#   E(\mathbf{w}) = (\mathbf{y} - \mathbf{X}\mathbf{w})^\top (\mathbf{y} - \mathbf{X}\mathbf{w})
# $$
# We now need to differentiate this *quadratic form* to find the minimum. We differentiate with respect to the *vector* $\mathbf{w}$. But before we do that, we'll expand the brackets in the quadratic form to obtain a series of scalar terms. The rules for bracket expansion across the vectors are similar to those for the scalar system giving,
# $$
#   (\mathbf{a} - \mathbf{b})^\top (\mathbf{c} - \mathbf{d}) = \mathbf{a}^\top \mathbf{c} - \mathbf{a}^\top \mathbf{d} - \mathbf{b}^\top \mathbf{c} + \mathbf{b}^\top \mathbf{d}
# $$
# which substituting for $\mathbf{a} = \mathbf{c} = \mathbf{y}$ and $\mathbf{b} = \mathbf{d} = \mathbf{X}\mathbf{w}$ gives
# $$
#   E(\mathbf{w}) = \mathbf{y}^\top \mathbf{y} - 2\mathbf{y}^\top \mathbf{X}\mathbf{w} + \mathbf{w}^\top \mathbf{X}^\top \mathbf{X}\mathbf{w}
# $$
# where we used the fact that $\mathbf{y}^\top \mathbf{X}\mathbf{w} = \mathbf{w}^\top \mathbf{X}^\top \mathbf{y}$. Now we can use our rules of differentiation to compute the derivative of this form, which is,
# $$
# \frac{\partial}{\partial \mathbf{w}}E(\mathbf{w}) = -2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top \mathbf{X}\mathbf{w}
# $$
# where we have exploited the fact that $\mathbf{X}^\top \mathbf{X}$ is symmetric to obtain this result.

# %% [markdown]
# ### Assignment Question 4
#
# Use the equivalence between our vector and our matrix formulations of linear regression, alongside our definition of vector derivates, to match the gradients we've computed directly for $\frac{\partial E(c, m)}{\partial c}$ and $\frac{\partial E(c, m)}{\partial m}$ to those for $\frac{\partial E(\mathbf{w})}{\partial \mathbf{w}}$.
#
# *10 marks*
#
# #### Hint for Question 4
#
# I think this question is asking you to show that $\displaystyle \begin{bmatrix} \frac{\partial}{\partial c} \\ \frac{\partial}{\partial m} \end{bmatrix} E(m,c) = \frac{\partial}{\partial\mathbf{w}} E(\mathbf{w})$ .

# %% [markdown]
# #### Question 4 Answer
#
# Given $\frac{\partial E(m,c)}{\partial c}$ from above in question 2:
#
# $$
#   \frac{\partial E(m,c)}{\partial c} = -\sum_{i=1}^n 2(y_i - mx_i - c)
# $$
#
# transform this equation into matrix form giving
#
# $$
#   \frac{\partial E(m,c)}{\partial c} = - 2\mathbf{y}^\top + 2\mathbf{X}^\top m + 2c
# $$
#
# Given $\frac{\partial E(m,c)}{\partial m}$ from above in question 2:
#
# $$
#   \frac{\partial E(m,c)}{\partial m} = -\sum_{i=1}^n 2x_i(y_i - mx_i - c)
# $$
#
# transform this equation into matrix form giving
#
# $$
#   \frac{\partial E(m,c)}{\partial m} = -2\mathbf{X}^\top\mathbf{y} + 2\mathbf{X}^\top\mathbf{X}m + 2c
# $$
#
# The equation for $\frac{\partial E(m,c)}{\partial m}$ is equal to $\frac{\partial}{\partial\mathbf{w}} E(\mathbf{w})$, however the equation I calculated for $\frac{\partial E(m,c)}{\partial c}$ does not equal.

# %% [markdown]
# ### Update Equation for Global Optimum
#
# Once again, we need to find the minimum of our objective function. Using our likelihood for multiple input regression we can now minimize for our parameter vector $\mathbf{w}$. Firstly, just as in the single input case, we seek stationary points by find parameter vectors that solve for when the gradients are zero,
# $$
#   \mathbf{0} = -2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top \mathbf{X}\mathbf{w}
# $$
# where $\mathbf{0}$ is a *vector* of zeros. Rearranging this equation we find the solution to be
# $$
#   \mathbf{w} = (\mathbf{X}^\top \mathbf{X})^{-1} \mathbf{X}^\top \mathbf{y}
# $$
# where $\mathbf{A}^{-1}$ denotes [*matrix inverse*](http://en.wikipedia.org/wiki/Invertible_matrix).
#
# ### Solving the Multivariate System
#
# The solution for $\mathbf{w}$ is given in terms of a matrix inverse, but computation of a matrix inverse requires, in itself, an algorithm to resolve it. You'll know this if you had to invert, by hand, a 3\times 3 matrix in high school. From a numerical stability perspective, it is also best not to compute the matrix inverse directly, but rather to ask the computer to *solve* the  system of linear equations given by
# $$
#   \mathbf{X}^\top \mathbf{X} \mathbf{w} = \mathbf{X}^\top \mathbf{y}
# $$
# for $\mathbf{w}$. This can be done in `numpy` using the command:

# %%
np.linalg.solve?

# %% [markdown]
# so we can obtain the solution using

# %%
w = np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y))
print(w)
# Out:
# [[  2.88952457e+01]
#  [ -1.29806477e-02]]

# %% [markdown]
# We can map it back to the liner regression and plot the fit as follows:

# %%
m = w[1]; c=w[0]
f_test = m*x_test + c
print(m)
print(c)
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')
# Out:
# [-0.01298065]
# [ 28.89524574]

# %% [markdown]
# ### Multivariate Linear Regression
#
# A major advantage of the new system is that we can build a linear regression on a multivariate system. The matrix calculus didn't specify what the length of the vector $\mathbf{x}$ should be, or equivalently the size of the design matrix.

# %% [markdown]
# ### Movie Body Count Data
#
# Let's load back in the movie body count data.

# %%
data = pods.datasets.movie_body_count()
movies = data['Y']

# %% [markdown]
# Let's remind ourselves of the features we've been provided with.

# %%
print(', '.join(movies.columns))
# Out:
# Film, Year, Body_Count, MPAA_Rating, Genre, Director, Actors, Length_Minutes, IMDB_Rating

# %% [markdown]
# Now we will build a design matrix based on the numeric features: year, Body_Count, Length_Minutes in an effort to predict the rating. We build the design matrix as follows:
#
# ### Relation to Single Input System
#
# Bias as an additional feature:

# %%
select_features = ['Year', 'Body_Count', 'Length_Minutes']
X = movies[select_features]
X['Eins'] = 1 # add a column for the offset
y = movies[['IMDB_Rating']]
# Out:
# C:\Users\Brian\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# Now let's perform a linear regression. But this time, we will create a pandas data frame for the result so we can store it in a form that we can visualise easily.

# %%
import pandas as pd

w = pd.DataFrame(data=np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y)),  # solve linear regression here
                 index = X.columns,  # columns of X become rows of w
                 columns=['regression_coefficient'])  # the column of X is the value of regression coefficient

# %% [markdown]
# We can check the residuals to see how good our estimates are.

# %%
(y - np.dot(X, w)).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A00C2B0>]], dtype=object)

# %% [markdown]
# Which shows our model *hasn't* yet done a great job of representation, because the spread of values is large. We can check what the rating is dominated by in terms of regression coefficients.

# %%
w
# Out:
#                 regression_coefficient
# Year                         -0.016280
# Body_Count                   -0.000995
# Length_Minutes                0.025386
# Eins                         36.508363

# %% [markdown]
# Although we have to be a little careful about interpretation because our input values live on different scales, however it looks like we are dominated by the bias, with a small negative effect for later films (but bear in mind the years are large, so this effect is probably larger than it looks) and a positive effect for length. So it looks like long earlier films generally do better, but the residuals are so high that we probably haven't modelled the system very well.

# %% [markdown]
# ### Solution with QR Decomposition
#
# Performing a `solve` instead of a matrix inverse is the more numerically stable approach, but we can do even better. A [QR-decomposition](http://en.wikipedia.org/wiki/QR_decomposition) of a matrix factorises it into a matrix which is an orthogonal matrix $\mathbf{Q}$, so that $\mathbf{Q}^\top \mathbf{Q} = \mathbf{I}$. And a matrix which is upper triangular, $\mathbf{R}$.
# \begin{align*}
#   \mathbf{X}^\top \mathbf{X} \boldsymbol{\beta} & = \mathbf{X}^\top \mathbf{y} \\
#   (\mathbf{Q}\mathbf{R})^\top (\mathbf{Q}\mathbf{R}) \boldsymbol{\beta} & = (\mathbf{Q}\mathbf{R})^\top \mathbf{y} \\
#   \mathbf{R}^\top (\mathbf{Q}^\top \mathbf{Q}) \mathbf{R} \boldsymbol{\beta} & = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y} \\
#   \mathbf{R}^\top \mathbf{R} \boldsymbol{\beta} & = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y} \\
#   \mathbf{R} \boldsymbol{\beta} & = \mathbf{Q}^\top \mathbf{y}
# \end{align*}
# This is a more numerically stable solution because it removes the need to compute $\mathbf{X}^\top \mathbf{X}$ as an intermediate. Computing $\mathbf{X}^\top \mathbf{X}$ is a bad idea because it involves squaring all the elements of $\mathbf{X}$ and thereby potentially reducing the numerical precision with which we can represent the solution. Operating on $\mathbf{X}$ directly preserves the numerical precision of the model.
#
# This can be more particularly seen when we begin to work with *basis functions* in the next session. Some systems that can be resolved with the QR decomposition can not be resolved by using solve directly.

# %%
import scipy as sp

Q, R = np.linalg.qr(X)
w = sp.linalg.solve_triangular(R, np.dot(Q.T, y))
w = pd.DataFrame(w, index=X.columns)
w
# Out:
#                         0
# Year            -0.016280
# Body_Count      -0.000995
# Length_Minutes   0.025386
# Eins            36.508363

# %% [markdown]
# ### Lectures by Neil Lawrence

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ui-uNlFHoms')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('78YNphT90-k')
